# %% [markdown]
# # Criação de Dashboard financeiro com dados pessoais
# ## Objetivo
# Extrair os dados de gastos pessoais da planilha de controle de despesas que é utilizada desde 2014 para demonstrar técnicas de tratamento de dados não estruturados.
# ## Procedimento
# O projeto irá seguir os seguintes passos:
# * Acessar o material através da API do Google Sheets, onde a planilha se encontra
# * Categorizar os dados por mês de ocorrência e categoria
# * Realizar análise das despesas ao longo do tempo
# * Disponibilizar os dados para consumo pelo PowerBI para criação de um Dashboard acessível online
# * Produzir dados anonimizados para divulgação online e criação de Portfolio
# #Execução
# ## Acessando as planilhas do Google Sheets
# O acesso direto ao Google Sheets se faz necessário pois as planilhas ainda são utilizadas e atualizadas semanalmente, portanto, o script deverá ser rodado periodicamente para manter o Dashboard atualizado.

# %%
# importação das bibliotecas necessárias
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import os
import numpy as np
from datetime import date
from datetime import timedelta
import hashlib
from pymongo import UpdateOne
from pymongo.mongo_client import MongoClient


#Configuração da Autenticação
scope = ["https://spreadsheets.google.com/feeds", 'https://www.googleapis.com/auth/drive']

'''
Para um script completo, utilizar a linha abaixo para obter o caminho do
arquivo de credenciais de forma dinâmica,
garantindo que funcione independentemente do
local onde o script seja executado.

> script_dir = os.path.dirname(os.path.abspath(__file__))

Para o caso do notebook iremos utilizar o cwd para obter
o caminho do arquivo de credenciais.
'''

if os.getcwd().endswith('scripts'):
  script_dir = os.getcwd()
  creds_path = os.path.join(script_dir, 'credentials.json')
  creds = ServiceAccountCredentials.from_json_keyfile_name(creds_path, scope)
  client = gspread.authorize(creds)
  planilha = client.open('Orçamento - João')
elif os.getcwd() == '/content':
  from google.colab import drive
  drive.mount('/content/drive')
  script_dir = '/content/drive/MyDrive/Estudos/Data Science/0.Portfolio/Finanças pessoais/scripts'
  creds_path = os.path.join(script_dir, 'credentials.json')
  creds = ServiceAccountCredentials.from_json_keyfile_name(creds_path, scope)
  client = gspread.authorize(creds)
  planilha = client.open('Orçamento - João')

# %% [markdown]
# ## Importando as abas da planilha
# Cada planilha da tabela possui uma formatação diferente ao longo dos anos, com um formato mais estável a partir de 2016 então teremos uma metodologia diferente por período.
# ### 2014
# A planilha apresenta na sua primeira coluna a descrição e nas demais os meses do ano, sendo que os valores foram sendo inseridos a partir do topo em cada virada de mês, resultando em uma planilha com muitos vazios por mês.
# Também não foi utilizada uma categorização padronizada de forma que a análise do comportamento de consumo se torna impraticável.
# A estratégia de tratamento dos dados deste ano será:
# * Dividir a tabela em subconjuntos por mês copiando a coluna de descrição e valor daquele mês
# * Inserir a coluna de datas de cada subconjunto
# * Empilhar as subseções para criar um único df com Descrição, Data e valor
# * Limpar valores nulos decorrentes do método de divisão e agrupamento dos subconjuntos
# * Categorizar os valores por receita e despesa de acordo com o sinal positivo ou negativo dos valores inseridos

# %%
# Acessar a aba de 2014
plan2014 = planilha.worksheet('2014')

# Obter os cabeçalhos da planilha de 2014
headers2014 = plan2014.row_values(1)

# Filtrar os cabeçalhos para remover os vazios
headers2014 = [h for h in headers2014 if h.strip()]

# importar os dados da planilha de 2014 somente dos cabeçalhos válidos
data2014 = plan2014.get_all_records(expected_headers=headers2014)
df2014 = pd.DataFrame(data2014).iloc[:227,:]
df2014
# Out:
#          Despesas 2014                 Categoria Parcela Fevereiro  Março  \
# 0
# 1              Aluguel                Essenciais       1             -925
# 2           Condomínio                Essenciais       1             -289
# 3            Tanomoshi  Dívidas e Financiamentos       1             3700
# 4              Mobilia                Essenciais       1            -1262
# ..                 ...                       ...     ...       ...    ...
# 222  Empréstimo errado  Dívidas e Financiamentos       1
# 223
# 224          Entrada X                  Receitas       1
# 225
# 226
#
#       Abril  Maio Junho Julho Agosto Setembro Outubro Novembro Dezembro
# 0
# 1            -950  -950  -910   -950    -1200   -1200    -1200    -1200
# 2    -28355  -285  -285  -285   -285     -285  -23355     -285           -685
# 3            3465
# 4            1300
# ..      ...   ...   ...   ...    ...      ...     ...      ...      ...   ...
# 222                                                                  -2
# 223
# 224                                                                2400
# 225
# 226
#
# [227 rows x 15 columns]

# %% [markdown]
# Com o dataframe de 2014 criado, podemos prossegir para a separação das colunas de cada mês e parear com as descrições.

# %%
# Seleção apenas das colunas de interesse para criação do subconjunto
df2014_fev = df2014[['Despesas 2014','Fevereiro']]
df2014_fev
# Out:
#          Despesas 2014 Fevereiro
# 0
# 1              Aluguel
# 2           Condomínio
# 3            Tanomoshi
# 4              Mobilia
# ..                 ...       ...
# 222  Empréstimo errado
# 223
# 224          Entrada X
# 225
# 226
#
# [227 rows x 2 columns]

# %% [markdown]
# Para um prcesso mais automatizado podemos criar um loop que gera as combinações de descrição e valor, além de adicionar uma coluna de data para o subset.

# %%
# Criamos uma lista vazia que irá abrigar os subconjuntos criados no loop
subsets_2014 = []

# Criamos também um dicionário que relaciona as labels de meses do cabeçalho
# com as datas que queremos inserir na coluna de data
map_datas2014 = {
    'Janeiro': '01/01/2014',
    'Fevereiro': '01/02/2014',
    'Março': '01/03/2014',
    'Abril': '01/04/2014',
    'Maio': '01/05/2014',
    'Junho': '01/06/2014',
    'Julho': '01/07/2014',
    'Agosto': '01/08/2014',
    'Setembro': '01/09/2014',
    'Outubro': '01/10/2014',
    'Novembro': '01/11/2014',
    'Dezembro': '01/12/2014'
}

# Abrimos o loop definindo as variáveis e iremos iterar sobre os itens do dict
for mes , data_despesa in map_datas2014.items():
    # Inicialmente verificamos se existe o mês do dict dentro do df de 2014
    if mes not in df2014.columns:
        continue

    # Criamos o primeiro subset selecionando a coluna de descrição e a
    # coluna do respectivo mês
    subset_df = df2014[['Despesas 2014', mes]].copy()

    # Adicionamos a coluna de data no formato definido no dict
    subset_df['Data'] = data_despesa

    # Renomeamos as colunas para o padrão desejado
    subset_df.rename(columns={mes: 'Valor','Despesas 2014':'Descrição'}, inplace=True)

    # Inserimos o subset dentro do contâiner criado anteriormente
    subsets_2014.append(subset_df)

# Transformamos a lista de dataframes num único dataframe para realizar
# a limpeza dos dados
despesas_2014 = pd.concat(subsets_2014, ignore_index=True)

# Vamos trocar o símbolo de decimal brasileiro para o americano
# para consumo pela ferramenta de BI e deixamos a configuração de visualização
# para a ferramenta de análise

# Para a substituição primeiro convertemos os valores para string para que
# possamos utilizar o método .replace() e depois convertemos de volta para número
despesas_2014['Valor'] = pd.to_numeric(
    despesas_2014['Valor'].astype(str).str.replace(',', '.'),
    errors='coerce'
)

# Removemos linhas vazias da coluna valor
despesas_2014 = despesas_2014.dropna(subset=['Valor'])

# Removemos linhas onde o valor é 0
despesas_2014 = despesas_2014[despesas_2014['Valor'] != 0]

# Removemos as linhas onde temos descrição vazia
despesas_2014 = despesas_2014[despesas_2014['Descrição'] != '']

despesas_2014
# Out:
#               Descrição   Valor        Data
# 228             Aluguel  -925.0  01/03/2014
# 229          Condomínio  -289.0  01/03/2014
# 230           Tanomoshi  3700.0  01/03/2014
# 231             Mobilia -1262.0  01/03/2014
# 232               Taiko   -60.0  01/03/2014
# ...                 ...     ...         ...
# 2489               Doce   -16.0  01/12/2014
# 2490           Encargos    -2.0  01/12/2014
# 2491           Remédios   -23.0  01/12/2014
# 2492  Empréstimo errado    -2.0  01/12/2014
# 2494          Entrada X  2400.0  01/12/2014
#
# [275 rows x 3 columns]

# %% [markdown]
# Para verificar a integridade dos dados, vamos verificar se temos ocorrência de valores sem descrição, pois ela será necessária quando formos sumarizar os dados em categorias posteriormente.

# %%
despesas_2014.loc[despesas_2014['Descrição'] == '']
# Out:
# Empty DataFrame
# Columns: [Descrição, Valor, Data]
# Index: []

# %% [markdown]
# Por fim vamos adicionar a coluna de tipo para diferenciar os valores entre receita e despesa, além de transformar todos os valores em positivos.

# %%
# Criamos a coluna tipo com base no sinal da coluna valor
despesas_2014['Tipo'] = np.where(despesas_2014['Valor'] < 0, 'D', 'R')

# Removemos então o sinal da coluna valor
despesas_2014['Valor'] = despesas_2014['Valor'].abs()

despesas_2014
# Out:
#               Descrição   Valor        Data Tipo
# 228             Aluguel   925.0  01/03/2014    D
# 229          Condomínio   289.0  01/03/2014    D
# 230           Tanomoshi  3700.0  01/03/2014    R
# 231             Mobilia  1262.0  01/03/2014    D
# 232               Taiko    60.0  01/03/2014    D
# ...                 ...     ...         ...  ...
# 2489               Doce    16.0  01/12/2014    D
# 2490           Encargos     2.0  01/12/2014    D
# 2491           Remédios    23.0  01/12/2014    D
# 2492  Empréstimo errado     2.0  01/12/2014    D
# 2494          Entrada X  2400.0  01/12/2014    R
#
# [275 rows x 4 columns]

# %% [markdown]
# ### 2015
# Em 2015 temos uma disposição semelhante a 2014 então podemos reproduzir o mesmo processo.

# %%
# Importamos a aba
plan2015 = planilha.worksheet('2015')

# Extraímos os cabeçalhos para passar ao método .get_all_records
headers2015 = plan2015.row_values(1)

# Criamos a lista de cabeçalhos excluido os vazios
headers2015 = [h for h in headers2015 if h.strip()]

# Extraímos os dados da planilha já filtrando as colunas
data2015 = plan2015.get_all_records(expected_headers=headers2015,numericise_ignore=['all'])

# Convertemos para um dataframe para manipulação
df2015 = pd.DataFrame(data2015)

# Vamos renomear a coluna na origem para simplificar o código mais adiante
df2015.rename(columns={'Despesas 2015': 'Descrição'}, inplace=True)

# Removemos as colunas 'Tipo', 'Categoria' e 'Parcela' do DataFrame de 2015
# pois não serão necessárias
df2015 = df2015.loc[:625, ~df2015.columns.isin(['Tipo', 'Categoria','Parcela'])]

df2015
# Out:
#            Descrição Janeiro Fevereiro Março    Abril  Maio Junho   Julho  \
# 0         Salário JV    2746      2624  2568  2637,44  2703  2909    2900
# 1       Adiantamento
# 2           13º João                                               833,41
# 3         Saque VGBL
# 4    WiiU extraviado
# ..               ...     ...       ...   ...      ...   ...   ...     ...
# 621         Panetone
# 622   Creme de leite
# 623  Taxi 18/12/2015
# 624
# 625
#
#     Agosto Setembro Outubro Novembro Dezembro
# 0     1626     1901    2699     1559     1560
# 1                               1352        0
# 2                               1000     1535
# 3           3826,98
# 4             -1350    1350
# ..     ...      ...     ...      ...      ...
# 621                                       -20
# 622                                     -10,2
# 623                                       -25
# 624
# 625
#
# [626 rows x 13 columns]

# %% [markdown]
# Com o dataframe preparado podemos realizar a reestruturação dos dados da mesma forma que fizemos em 2014.

# %%
# Criação do contâiner e dicionário para execução do loop
subsets_2015 = []
map_datas2015 = {
    'Janeiro': '01/01/2015',
    'Fevereiro': '01/02/2015',
    'Março': '01/03/2015',
    'Abril': '01/04/2015',
    'Maio': '01/05/2015',
    'Junho': '01/06/2015',
    'Julho': '01/07/2015',
    'Agosto': '01/08/2015',
    'Setembro': '01/09/2015',
    'Outubro': '01/10/2015',
    'Novembro': '01/11/2015',
    'Dezembro': '01/12/2015'
}

for mes , data_despesa in map_datas2015.items():
    # Checar se o mês do dict existe entre as colunas do df
    if mes not in df2015.columns:
        continue

    # Criação do subset com as colunas que contem as descrições e os valores
    subset_df = df2015[['Descrição', mes]].copy()

    # Criamos a coluna de data
    subset_df['Data'] = data_despesa

    # Renomeia a coluna com valores
    subset_df.rename(columns={mes: 'Valor'}, inplace=True)

    # Adiciona o subset ao contâiner
    subsets_2015.append(subset_df)

# Convertemos os subsets do contâiner em um dataframe único
despesas_2015 = pd.concat(subsets_2015, ignore_index=True)

# Removemos linhas sem valor
despesas_2015 = despesas_2015[despesas_2015['Valor'] != '']

# Substituímos o caracter de decimal
despesas_2015['Valor'] = despesas_2015['Valor'].astype(str).str.replace(',', '.').astype(float)

# Definimos o tipo de operação pelo sinal do valor
despesas_2015['Tipo'] = np.where(despesas_2015['Valor'] < 0, 'D', 'R')

# Convertemos de volta para valor para eliminação do sinal
despesas_2015['Valor'] = despesas_2015['Valor'].astype(float).abs()

despesas_2015
# Out:
#                Descrição   Valor        Data Tipo
# 0             Salário JV  2746.0  01/01/2015    R
# 9     Salário Marilia 15   504.0  01/01/2015    R
# 12               Aluguel  1200.0  01/01/2015    D
# 17                 Taiko    80.0  01/01/2015    D
# 19           Eletropaulo    51.0  01/01/2015    D
# ...                  ...     ...         ...  ...
# 7505             Mercado    13.0  01/12/2015    D
# 7506      Presente chefa    20.0  01/12/2015    D
# 7507            Panetone    20.0  01/12/2015    D
# 7508      Creme de leite    10.2  01/12/2015    D
# 7509     Taxi 18/12/2015    25.0  01/12/2015    D
#
# [855 rows x 4 columns]

# %% [markdown]
# Seguindo a mesma lógica de análise de 2014, vamos verificar se temos linhas sem descrição.

# %%
despesas_2015.loc[despesas_2015['Descrição'] == '']
# Out:
# Empty DataFrame
# Columns: [Descrição, Valor, Data, Tipo]
# Index: []

# %% [markdown]
# ## 2016
# Em 2016 o formato da planilha mudou para algo mais próximo do atual, com cada mês utilizando 3 colunas (Descrição, Tipo e Valor).
#
# O tratamento dos dados é um pouco diferente pois não temos mais tantos vazios na planilha mas agora precisamos:
# * Isolar as linhas com valores na importação pois temos cabeçalhos neste modelo
# * Diferenciar valores de receita e despesa conforme valor (positivo ou negativo)
# * Dividir e empilhar a planilha para criar um único df
#
# ### Isolar valores
#
# Inicialmente iremos isolar apenas as linhas com valores que serão processados.

# %%
# Importação da aba de 2016
plan2016 = planilha.worksheet('2016')

# Extraímos os dados da planilha já filtrando as colunas
data2016 = plan2016.get_all_records(numericise_ignore=['all'])

# Convertemos para um dataframe para manipulação
df2016 = pd.DataFrame(data2016)

# Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
# coluna e então removê-la pois não será mais necessária
df2016 = df2016.loc[df2016['C'] != 'C', :].iloc[:,1:]

df2016
# Out:
#                       DESC_JAN C_JAN      JAN                   DESC_FEV  \
# 10             JV - Quinto dia     0     1560            JV - Quinto dia
# 11           JV - Adiantamento     0  1351,91          JV - Adiantamento
# 12                      Ajuste     0  1881,24  Adiantamento mês seguinte
# 13                 13º Marilia     0                           Vale João
# 14   Adiantamento mês seguinte     0     1352               Vale Marilia
# ..                         ...   ...      ...                        ...
# 178
# 179
# 180
# 181
# 182
#
#     C_FEV    FEV                   DESC_MAR C_MAR    MAR  \
# 10      0   1560            JV - Quinto dia     0   1560
# 11      0  -0,09          JV - Adiantamento     0  -0,09
# 12      0   1352  Adiantamento mês seguinte     0   1352
# 13      0    405                  Vale João     0    320
# 14      0                      Vale Marilia     0    522
# ..    ...    ...                        ...   ...    ...
# 178
# 179
# 180
# 181
# 182
#
#                       DESC_ABR  ...   SET                   DESC_OUT C_OUT  \
# 10             JV - Quinto dia  ...  1461            JV - Quinto dia     0
# 11           JV - Adiantamento  ...                JV - Adiantamento     0
# 12   Adiantamento mês seguinte  ...  1439  Adiantamento mês seguinte     0
# 13                   Vale João  ...   354                  Vale João     0
# 14                Vale Marilia  ...     0                    Mercado     1
# ..                         ...  ...   ...                        ...   ...
# 178                             ...
# 179                             ...
# 180                             ...
# 181                             ...
# 182                             ...
#
#       OUT                   DESC_NOV C_NOV      NOV  \
# 10   1565            JV - Quinto dia     0     1455
# 11                            Férias     0  4500,72
# 12   1485  Adiantamento mês seguinte     0     1485
# 13    367                   13º João     0     1857
# 14      0                    Mercado     1
# ..    ...                        ...   ...      ...
# 178
# 179
# 180
# 181
# 182
#
#                       DESC_DEZ C_DEZ   DEZ
# 10             JV - Quinto dia     0   591
# 11           JV - Adiantamento     0
# 12   Adiantamento mês seguinte     0  1485
# 13                    13º João     0  1306
# 14                     Mercado    NU
# ..                         ...   ...   ...
# 178
# 179
# 180
# 181
# 182
#
# [173 rows x 36 columns]

# %% [markdown]
# ### Dividir a planilha em subsets
#
# Agora devemos criar um laço parecido com os anteriores, utilizando a coluna principal com valores e com cabeçalho com nome do mês (JAN, FEV, etc) como referência.

# %%
#Criamos a lista e o dict de datas para criar a coluna posteriormente
subsets_2016 = []
map_datas2016 = {
    'JAN': '01/01/2016',
    'FEV': '01/02/2016',
    'MAR': '01/03/2016',
    'ABR': '01/04/2016',
    'MAI': '01/05/2016',
    'JUN': '01/06/2016',
    'JUL': '01/07/2016',
    'AGO': '01/08/2016',
    'SET': '01/09/2016',
    'OUT': '01/10/2016',
    'NOV': '01/11/2016',
    'DEZ': '01/12/2016'
}

#O loop faz a divisão em subsets que são armazenados em uma lista
for mes , data_despesa in map_datas2016.items():
    # Verificamos se o mês do dict existe entre as colunas do df de 2016,
    # caso não exista continuamos para a próxima iteração do loop
    if mes not in df2016.columns:
        continue

    #Encontramos o índice da coluna para usar de referência
    i_col = df2016.columns.get_loc(mes)

    # Utilizamos o iloc para selecionar as colunas pois estão
    # em posições relativas ao mês
    subset_df = df2016.iloc[:, (i_col - 2):i_col + 1].copy()

    #Criamos a coluna de data utilizando o dict criado anteriormente
    subset_df['Data'] = data_despesa

    #Renomeamos as colunas para padronizar com os outros anos
    subset_df.rename(
        columns={mes : 'Valor',
                 f'DESC_{mes}':'Descrição',
                 f'C_{mes}':'Código'},
                   inplace=True
                   )

    #Armazenamos o subset na lista criada anteriormente
    subsets_2016.append(subset_df)

#Concatenamos a lista com os subsets em um único DataFrame
despesas_2016 = pd.concat(subsets_2016, ignore_index=True)

#Convertemos a coluna de valor para numérico e tratamos os erros
despesas_2016['Valor'] = pd.to_numeric(
    despesas_2016['Valor'].astype(str).str.replace(',', '.'),
    errors='coerce'
)

#Removemos as linhas onde o valor é zero ou nulo
despesas_2016 = despesas_2016.loc[(despesas_2016['Valor'] != 0) & (despesas_2016['Valor'].notna())]

#Criamos a coluna de tipo para diferenciar receitas e despesas
despesas_2016['Tipo'] = np.where(despesas_2016['Código'] == 'R', 'R', 'D')

#Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
despesas_2016['Tipo'] = np.where((despesas_2016['Tipo'] == 'D') & (despesas_2016['Valor'] > 0), 'RE', despesas_2016['Tipo'])

#Removemos a coluna de código pois não será mais necessária
despesas_2016 = despesas_2016.drop(columns=['Código'])

#Transformamos os valores da coluna valor para positivos
despesas_2016['Valor'] = despesas_2016['Valor'].abs()

despesas_2016
# Out:
#                       Descrição    Valor        Data Tipo
# 0               JV - Quinto dia  1560.00  01/01/2016   RE
# 1             JV - Adiantamento  1351.91  01/01/2016   RE
# 2                        Ajuste  1881.24  01/01/2016   RE
# 4     Adiantamento mês seguinte  1352.00  01/01/2016   RE
# 5                     Vale João   379.00  01/01/2016   RE
# ...                         ...      ...         ...  ...
# 2024         Reembolso de pizza    52.80  01/12/2016   RE
# 2025      Materiais de Manicure    16.94  01/12/2016    D
# 2026              Café da manhã    37.50  01/12/2016    D
# 2027    Reembolso café da manhã    29.20  01/12/2016   RE
# 2028      Muamba do Guilhermino    27.00  01/12/2016    D
#
# [1304 rows x 4 columns]

# %%
# Verificamos as linhas que possuem descrição vazia
despesas_2016.loc[despesas_2016['Descrição'] == '']
# Out:
# Empty DataFrame
# Columns: [Descrição, Valor, Data, Tipo]
# Index: []

# %% [markdown]
# ## 2017
#
# Como a planilha manteve sua estrutura em 2017, podemos simplesmente repetir o código, alterando apenas o ano das variáveis.

# %%
#Importamos os dados de 2017 da planilha e criamos o DataFrame
plan2017 = planilha.worksheet('2017')
data2017 = plan2017.get_all_records(numericise_ignore=['all'])
df2017 = pd.DataFrame(data2017)

#Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
#coluna e então remover a coluna pois não será mais necessária
df2017 = df2017.loc[df2017['C'] != 'C', :].iloc[:,1:]

#Criamos a lista e o dict de datas para criar a coluna posteriormente
subsets_2017 = []
map_datas2017 = {
    'JAN': '01/01/2017',
    'FEV': '01/02/2017',
    'MAR': '01/03/2017',
    'ABR': '01/04/2017',
    'MAI': '01/05/2017',
    'JUN': '01/06/2017',
    'JUL': '01/07/2017',
    'AGO': '01/08/2017',
    'SET': '01/09/2017',
    'OUT': '01/10/2017',
    'NOV': '01/11/2017',
    'DEZ': '01/12/2017'
}

#O loop faz a divisão em subsets que são armazenados em uma lista
for mes , data_despesa in map_datas2017.items():

    # Verificamos se o mês do dict existe entre as colunas do df de 2017
    if mes not in df2017.columns:
        continue

    #Encontramos o índice da coluna para usar de referência
    i_col = df2017.columns.get_loc(mes)
    subset_df = df2017.iloc[:, (i_col - 2):i_col + 1].copy()

    #Criamos a coluna de data utilizando o dict criado anteriormente
    subset_df['Data'] = data_despesa

    #Renomeamos as colunas para padronizar com os outros anos
    subset_df.rename(
        columns={mes : 'Valor',
                 f'DESC_{mes}':'Descrição',
                 f'C_{mes}':'Código'},
                   inplace=True
                   )

    #Armazenamos o subset na lista criada anteriormente
    subsets_2017.append(subset_df)

#Concatenamos a lista com os subsets em um único DataFrame
despesas_2017 = pd.concat(subsets_2017, ignore_index=True)

#Convertemos a coluna de valor para numérico e tratamos os erros
despesas_2017['Valor'] = pd.to_numeric(
    despesas_2017['Valor'].astype(str).str.replace(',', '.'),
    errors='coerce'
)

#Removemos as linhas onde o valor é zero ou nulo
despesas_2017 = despesas_2017.loc[(despesas_2017['Valor'] != 0) & (despesas_2017['Valor'].notna())]

#Criamos a coluna de tipo para diferenciar receitas e despesas
despesas_2017['Tipo'] = np.where(despesas_2017['Código'] == 'R', 'R', 'D')

#Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
despesas_2017['Tipo'] = np.where((despesas_2017['Tipo'] == 'D') & (despesas_2017['Valor'] > 0), 'RE', despesas_2017['Tipo'])

#Removemos a coluna de código pois não será mais necessária
despesas_2017 = despesas_2017.drop(columns=['Código'])

#Transformamos os valores da coluna valor para positivos
despesas_2017['Valor'] = despesas_2017['Valor'].abs()

despesas_2017
# Out:
#                       Descrição    Valor        Data Tipo
# 0               JV - Quinto dia   582.00  01/01/2017   RE
# 2     Adiantamento mês seguinte  1485.00  01/01/2017   RE
# 4                       Mercado    28.87  01/01/2017    D
# 5                       Aluguel  1200.00  01/01/2017    D
# 6                    Condomínio   270.39  01/01/2017    D
# ...                         ...      ...         ...  ...
# 1908                   Mercadao     5.00  01/12/2017    D
# 1909             Passagem momoi    20.00  01/12/2017    D
# 1910              Desenho Luana    65.00  01/12/2017   RE
# 1911                   Encargos     1.13  01/12/2017    D
# 1912                     Acerto    54.91  01/12/2017   RE
#
# [1248 rows x 4 columns]

# %%
despesas_2017.loc[despesas_2017['Descrição'] == '']
# Out:
# Empty DataFrame
# Columns: [Descrição, Valor, Data, Tipo]
# Index: []

# %% [markdown]
# ## 2018
# O processo pode ser repetido novamente em 2018.

# %%
#Importamos os dados de 2018 da planilha e criamos o DataFrame
plan2018 = planilha.worksheet('2018')
data2018 = plan2018.get_all_records(numericise_ignore=['all'])
df2018 = pd.DataFrame(data2018)

#Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
#coluna e então remover a coluna pois não será mais necessária
df2018 = df2018.loc[df2018['C'] != 'C', :].iloc[:,1:]

#Criamos a lista e o dict de datas para criar a coluna posteriormente
subsets_2018 = []
map_datas2018 = {
    'JAN': '01/01/2018',
    'FEV': '01/02/2018',
    'MAR': '01/03/2018',
    'ABR': '01/04/2018',
    'MAI': '01/05/2018',
    'JUN': '01/06/2018',
    'JUL': '01/07/2018',
    'AGO': '01/08/2018',
    'SET': '01/09/2018',
    'OUT': '01/10/2018',
    'NOV': '01/11/2018',
    'DEZ': '01/12/2018'
}

#O loop faz a divisão em subsets que são armazenados em uma lista
for mes , data_despesa in map_datas2018.items():
    # Verificamos se o mês do dict existe entre as colunas do df de 2018
    if mes not in df2018.columns:
        continue

    #Encontramos o índice da coluna para usar de referência
    i_col = df2018.columns.get_loc(mes)
    subset_df = df2018.iloc[:, (i_col - 2):i_col + 1].copy()

    #Criamos a coluna de data utilizando o dict criado anteriormente
    subset_df['Data'] = data_despesa

    #Renomeamos as colunas para padronizar com os outros anos
    subset_df.rename(
        columns={mes : 'Valor',
                 f'DESC_{mes}':'Descrição',
                 f'C_{mes}':'Código'},
                  inplace=True
                  )

    #Armazenamos o subset na lista criada anteriormente
    subsets_2018.append(subset_df)

#Concatenamos a lista com os subsets em um único DataFrame
despesas_2018 = pd.concat(subsets_2018, ignore_index=True)

#Convertemos a coluna de valor para numérico e tratamos os erros
despesas_2018['Valor'] = pd.to_numeric(
    despesas_2018['Valor'].astype(str).str.replace(',', '.'),
    errors='coerce'
)

#Removemos as linhas onde o valor é zero ou nulo
despesas_2018 = despesas_2018.loc[(despesas_2018['Valor'] != 0) & (despesas_2018['Valor'].notna())]

#Criamos a coluna de tipo para diferenciar receitas e despesas
despesas_2018['Tipo'] = np.where(despesas_2018['Código'] == 'R', 'R', 'D')

#Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
despesas_2018['Tipo'] = np.where((despesas_2018['Tipo'] == 'D') & (despesas_2018['Valor'] > 0), 'RE', despesas_2018['Tipo'])

#Removemos a coluna de categoria pois não será mais necessária
despesas_2018 = despesas_2018.drop(columns=['Código'])

#Transformamos os valores da coluna valor para positivos
despesas_2018['Valor'] = despesas_2018['Valor'].abs()

despesas_2018
# Out:
#                       Descrição    Valor        Data Tipo
# 1               JV - Quinto dia  1828.00  01/01/2018   RE
# 3     Adiantamento mês seguinte  1858.00  01/01/2018   RE
# 5                     Aluguel 7  1200.00  01/01/2018    D
# 6                 Condomínio 15   305.15  01/01/2018    D
# 7                      Taiko 15   100.00  01/01/2018    D
# ...                         ...      ...         ...  ...
# 1686                  Emp. Nu B   360.00  01/12/2018   RE
# 1688           Yuzu Restaurante   110.00  01/12/2018    D
# 1689                   Autopass    10.00  01/12/2018    D
# 1690         Seguro prestamista   125.22  01/12/2018   RE
# 1691              Acerto débito   162.99  01/12/2018   RE
#
# [954 rows x 4 columns]

# %%
# Verificamos as linhas que possuem descrição vazia
despesas_2018.loc[despesas_2018['Descrição'] == '']
# Out:
# Empty DataFrame
# Columns: [Descrição, Valor, Data, Tipo]
# Index: []

# %% [markdown]
# ## 2019 a 2025
# Em 2019 o processo é semelhante mas vamos adaptar a criação da coluna de tipo de despesa pois agora a maioria dos valores serão positivos mas temos um código específico para valores de receita. Os valores negativos que ainda existe são entradas de reembolso.
#
# Podemos reproduzir este mesmo processo para todos os anos seguintes pois temos o mesmo formato de planilha daqui para frente. Com isso podemos fazer um loop para deixar o código mais resumido.

# %%
# Criamos uma lista com os anos para iterar sobre as abas de 2019 a 2025
abas = [str(ano) for ano in range(2019, 2026)]

# Criamos o contâiner que irá armazenar os subsets
despesas_2019_a_2025 = []

# Criamos um loop acima do loop de subsets para iterar
#  a importação dos dados de cada ano
for ano in abas:

    #Importamos os dados do ano da planilha e criamos o DataFrame
    plan_ano = planilha.worksheet(ano)
    data_ano = plan_ano.get_all_records(numericise_ignore=['all'])
    df_ano = pd.DataFrame(data_ano)

    #Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
    #coluna e então remover a coluna pois não será mais necessária
    df_ano = df_ano.loc[df_ano['C'] != 'C', :].iloc[:,1:]

    #Criamos a lista e o dict de datas para criar a coluna posteriormente
    subsets_ano = []
    map_datas_ano = {
        'JAN': f'01/01/{ano}',
        'FEV': f'01/02/{ano}',
        'MAR': f'01/03/{ano}',
        'ABR': f'01/04/{ano}',
        'MAI': f'01/05/{ano}',
        'JUN': f'01/06/{ano}',
        'JUL': f'01/07/{ano}',
        'AGO': f'01/08/{ano}',
        'SET': f'01/09/{ano}',
        'OUT': f'01/10/{ano}',
        'NOV': f'01/11/{ano}',
        'DEZ': f'01/12/{ano}'
    }

    #O loop faz a divisão em subsets que são armazenados em uma lista
    for mes , data_despesa in map_datas_ano.items():

        # Verificamos se o mês do dict existe entre as colunas do df do ano
        if mes not in df_ano.columns:
            continue

        #Encontramos o índice da coluna para usar de referência
        i_col = df_ano.columns.get_loc(mes)
        subset_df = df_ano.iloc[:, (i_col - 2):i_col + 1].copy()

        #Criamos a coluna de data utilizando o dict criado anteriormente
        subset_df['Data'] = data_despesa

        #Renomeamos as colunas para padronizar com os outros anos
        subset_df.rename(
            columns={mes : 'Valor',
                     f'DESC_{mes}':'Descrição',
                     f'C_{mes}':'Código'},
                       inplace=True
                       )

        #Armazenamos o subset na lista criada anteriormente
        subsets_ano.append(subset_df)

    #Concatenamos a lista com os subsets em um único DataFrame
    subset_2019_a_2025 = pd.concat(subsets_ano, ignore_index=True)

    #Convertemos a coluna de valor para numérico e tratamos os erros
    subset_2019_a_2025['Valor'] = pd.to_numeric(
        subset_2019_a_2025['Valor'].astype(str).str.replace(',', '.'),
        errors='coerce'
    )

    #Adicionamos o subset ao DataFrame principal
    despesas_2019_a_2025.append(subset_2019_a_2025)

#Concatenamos todos os subsets em um único DataFrame
despesas_2019_a_2025 = pd.concat(despesas_2019_a_2025, ignore_index=True)

#Removemos as linhas onde o valor é zero ou nulo
despesas_2019_a_2025 = despesas_2019_a_2025.loc[(despesas_2019_a_2025['Valor'] != 0) & (despesas_2019_a_2025['Valor'].notna())]

#Criamos a coluna de tipo para diferenciar receitas e despesas
despesas_2019_a_2025['Tipo'] = np.where(despesas_2019_a_2025['Código'] == 'R', 'R', 'D')

#Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
despesas_2019_a_2025['Tipo'] = np.where((despesas_2019_a_2025['Tipo'] == 'D') & (despesas_2019_a_2025['Valor'] < 0), 'RE', despesas_2019_a_2025['Tipo'])

#Removemos a coluna de categoria pois não será mais necessária
despesas_2019_a_2025 = despesas_2019_a_2025.drop(columns=['Código'])

#Transformamos os valores da coluna valor para positivos
despesas_2019_a_2025['Valor'] = despesas_2019_a_2025['Valor'].abs()

despesas_2019_a_2025
# Out:
#              Descrição   Valor        Data Tipo
# 0              Salário  3785.0  01/01/2019    R
# 1                  13º   383.0  01/01/2019    R
# 2          Presente YB   300.0  01/01/2019    R
# 4          7 - Aluguel  1200.0  01/01/2019    D
# 5      15 - Condomínio   259.0  01/01/2019    D
# ...                ...     ...         ...  ...
# 18546            Karen    16.0  01/12/2025    R
# 18547           Flavia    48.0  01/12/2025    R
# 18548           Faxina   230.0  01/12/2025    D
# 18549           Karine     8.0  01/12/2025    R
# 18550            Bolão    60.0  01/12/2025    D
#
# [12519 rows x 4 columns]

# %%
# Verificamos as linhas que possuem descrição vazia
despesas_2019_a_2025.loc[despesas_2019_a_2025['Descrição'] == '']
# Out:
# Empty DataFrame
# Columns: [Descrição, Valor, Data, Tipo]
# Index: []

# %% [markdown]
# ## Categorização das despesas até 2025
#
# O próximo passo será a categorização das despesas em grupos que permitam uma avaliação do perfil de gastos ao longo do tempo.
#
# Para isso vamos unificar os dataframes até o momento e extrair os valores únicos da coluna descrição para criar uma tabela de/para que será exportada para o excel para categorização manual.

# %%
# Concatenanamos todas as listas geradas num único DataFrame
despesas_ant_2025 = pd.concat([despesas_2014,
                               despesas_2015,
                               despesas_2016,
                               despesas_2017,
                               despesas_2018,despesas_2019_a_2025],
                               ignore_index=True)

# Extraímos a lista de descrições únicas para criar a tabela de correspondência
desc_unicas = despesas_ant_2025['Descrição'].loc[despesas_ant_2025['Descrição'] != ''].unique().tolist()

# Transformamos a lista de descrições únicas num DataFrame
desc_unicas = pd.DataFrame(desc_unicas, columns=['Descrição'])

desc_unicas

# A tabela de correspondência é salva em um arquivo Excel para ser preenchida posteriormente
desc_unicas.to_excel('Tabela_De_Para_Para_Preencher.xlsx', index=False)

# %% [markdown]
# ### Categorias que serão utilizadas
# As categorias principais são listadas abaixo:
# * Essenciais
#     * Aluguel ou prestação do imóvel, condomínio, IPTU, água, luz, gás, internet, telefone.
# * Mercado
#     * Supermercado, feiras, açougues, padarias, restaurantes, lanches, drogaria.
# * Transporte
#     * Combustível, estacionamento, transporte público, aplicativos.
# * Veículo
#     * Parcelas, manutenções, IPVA, Seguros.
# * Saúde
#     * Plano de saúde, consultas, exames, medicamentos, terapias.
# * Educação
#     * Mensalidades (escola, cursos), material escolar, livros, uniformes.
# * Despesas Pessoais
#     * Roupas, calçados, produtos de higiene, cosméticos, academia, cabeleireiro.
# * Lazer e Entretenimento
#     * Streaming, cinema, shows, passeios, viagens, hobbies.
# * Financeiro
#     * Parcelas de empréstimos, tarifas, juros, impostos.
# * Investimentos e Poupança
#     * Aportes em investimentos, reserva de emergência, poupança para objetivos.
# * Delivery
#     * Jantares fora, pedir comida. Alimentação que não foi preparada em casa.
# * Receitas
#     * Recebíveis de qualquer espécie
# * Casa
#     * Gastos com manutenção e aquisições para a casa
# * Pets
#     * Despesas com animais como ração, plano de saúde e consultas veterinárias
# * Outros Gastos
#     * Presentes, doações, manutenções inesperadas e despesas eventuais.
#
# ## Categorização do histórico
#
# No DataFrame com o histórico até 2025 iremos criar a coluna de categoria utilizando a tabela de-para com as categorias:

# %%
# Obtemos o caminho para a tabela preenchida
de_para_path = os.path.join(script_dir, 'Tabela_De_Para_Preenchida.xlsx')

# Armazenamos o dataframe
de_para_2014_2025 = pd.read_excel(de_para_path)

# Criamos um dicionário a partir da tabela de correspondência
de_para_2014_2025_dict = de_para_2014_2025.set_index('Descrição')['Categoria'].to_dict()

# Criamos a coluna de categoria com base no mapeamento
despesas_ant_2025['Categoria'] = despesas_ant_2025['Descrição'].map(de_para_2014_2025_dict)

despesas_ant_2025
# Out:
# e:\Python\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#         Descrição   Valor        Data Tipo               Categoria
# 0         Aluguel   925.0  01/03/2014    D              Essenciais
# 1      Condomínio   289.0  01/03/2014    D              Essenciais
# 2       Tanomoshi  3700.0  01/03/2014    R              Financeiro
# 3         Mobilia  1262.0  01/03/2014    D                    Casa
# 4           Taiko    60.0  01/03/2014    D  Lazer e Entretenimento
# ...           ...     ...         ...  ...                     ...
# 17150       Karen    16.0  01/12/2025    R              Financeiro
# 17151      Flavia    48.0  01/12/2025    R              Financeiro
# 17152      Faxina   230.0  01/12/2025    D              Essenciais
# 17153      Karine     8.0  01/12/2025    R              Financeiro
# 17154       Bolão    60.0  01/12/2025    D       Despesas Pessoais
#
# [17155 rows x 5 columns]

# %% [markdown]
# Vamos verificar se temos alguma célula vazia na descrição ou nos valores:

# %%
despesas_ant_2025.loc[(despesas_ant_2025['Descrição'] == '') | (despesas_ant_2025['Valor'] == '')].size
# Out:
# 0

# %% [markdown]
# ## Tratamento dos dados pós 2026
# A partir de 2026 alteramos o input de dados na tabela para que o usuário passe a categorizar as entradas junto com sua inserção, deixando o código responsável apenas pela estruturação e disponibilização para consumo pelo pipeline.
#
# O formato da tabela segue o mesmo dos últimos anos, apenas acrescentando uma coluna de categoria em cada mês. Vamos ajustar o procedimento a partir de 2019 para que considere esta coluna

# %%
# Cria uma lista com os nomes das abas a partir de 2026
abas_pos_2026 = [aba.title
                 for aba in planilha.worksheets(exclude_hidden=True)
                 if aba.title not in [str(i) for i in range(2014, 2026)] and aba.title != 'Categorias']

# Criamos o contâiner que irá armazenar os subsets
despesas_pos_2026 = []

# Realizamos o loop para importar os dados de cada aba
for ano in abas_pos_2026:

    #Importamos os dados do ano da planilha e criamos o DataFrame
    plan_ano = planilha.worksheet(ano)
    data_ano = plan_ano.get_all_records(numericise_ignore=['all'])
    df_ano = pd.DataFrame(data_ano)

    #Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
    #coluna e então remover a coluna pois não será mais necessária
    df_ano = df_ano.loc[df_ano['C'] != 'C', :].iloc[:,1:]

    #Criamos a lista e o dict de datas para criar a coluna posteriormente
    subsets_ano = []
    map_datas_ano = {
        'JAN': f'01/01/{ano}',
        'FEV': f'01/02/{ano}',
        'MAR': f'01/03/{ano}',
        'ABR': f'01/04/{ano}',
        'MAI': f'01/05/{ano}',
        'JUN': f'01/06/{ano}',
        'JUL': f'01/07/{ano}',
        'AGO': f'01/08/{ano}',
        'SET': f'01/09/{ano}',
        'OUT': f'01/10/{ano}',
        'NOV': f'01/11/{ano}',
        'DEZ': f'01/12/{ano}'
    }

    #O loop faz a divisão em subsets que são armazenados em uma lista
    for mes , data_despesa in map_datas_ano.items():

        # Verificamos se o mês do dict existe entre as colunas do df do ano
        if mes not in df_ano.columns:
            continue

        #Encontramos o índice da coluna para usar de referência
        i_col = df_ano.columns.get_loc(mes)
        subset_df = df_ano.iloc[:, (i_col - 3):i_col + 1].copy()

        #Criamos a coluna de data utilizando o dict criado anteriormente
        subset_df['Data'] = data_despesa

        #Renomeamos as colunas para padronizar com os outros anos
        subset_df.rename(
            columns={mes : 'Valor',
                     f'DESC_{mes}':'Descrição',
                     f'C_{mes}':'Código',
                     f'CAT_{mes}':'Categoria'
                     },
                       inplace=True
                       )
        #Armazenamos o subset na lista criada anteriormente
        subsets_ano.append(subset_df)

    #Concatenamos a lista com os subsets em um único DataFrame
    subset_pos_2026 = pd.concat(subsets_ano, ignore_index=True)

    #Convertemos a coluna de valor para numérico e tratamos os erros
    subset_pos_2026['Valor'] = pd.to_numeric(
        subset_pos_2026['Valor'].astype(str).str.replace(',', '.'),
        errors='coerce'
    )

    #Adicionamos o subset ao DataFrame principal
    despesas_pos_2026.append(subset_pos_2026)

#Concatenamos todos os subsets em um único DataFrame
despesas_pos_2026 = pd.concat(despesas_pos_2026, ignore_index=True)

#Removemos as linhas onde o valor é zero ou nulo
despesas_pos_2026 = despesas_pos_2026.loc[(despesas_pos_2026['Valor'] != 0) & (despesas_pos_2026['Valor'].notna())]

#Criamos a coluna de tipo para diferenciar receitas e despesas
despesas_pos_2026['Tipo'] = np.where(despesas_pos_2026['Código'] == 'R', 'R', 'D')

#Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
despesas_pos_2026['Tipo'] = np.where((despesas_pos_2026['Tipo'] == 'D') & (despesas_pos_2026['Valor'] < 0), 'RE', despesas_pos_2026['Tipo'])

#Removemos a coluna de código pois não será mais necessária
despesas_pos_2026 = despesas_pos_2026.drop(columns=['Código'])

#Transformamos os valores da coluna valor para positivos
despesas_pos_2026['Valor'] = despesas_pos_2026['Valor'].abs()

despesas_pos_2026
# Out:
#               Descrição          Categoria   Valor        Data Tipo
# 2              04 - Luz         Essenciais  186.24  01/01/2026    D
# 3             21 - Vivo         Essenciais  100.00  01/01/2026    D
# 4                   Gás         Essenciais  125.00  01/01/2026    D
# 5             17 - Vivo         Essenciais  150.00  01/01/2026    D
# 6          Seguro Carro            Veículo  378.60  01/01/2026    D
# ...                 ...                ...     ...         ...  ...
# 1993         Transporte         Transporte  599.00  01/12/2026    D
# 1994           Delivery           Delivery  947.00  01/12/2026    D
# 1995  Despesas pessoais  Despesas Pessoais  780.00  01/12/2026    D
# 1997               Casa               Casa  580.00  01/12/2026    D
# 1998     NuBank Marilia  Despesas Pessoais  300.00  01/12/2026    D
#
# [714 rows x 5 columns]

# %% [markdown]
# ## Modularização das funções de extração
#
# Para deixar o código mais limpo e mais inteligível iremos definir funções específicas de extração de dados para que seja possível obter dados atualizados independente do ano, apenas informando o período anual desejado.
#
# Para isso iremos padronizar a geração de dicionários, a categorização de despesas e padronizar as funções desenvolvidas até então para cada um dos conjuntos de períodos.

# %%
def gerar_id_unico(linha):
    # Converte os dados para string e gera um código MD5
    string_base = f"{linha['Data']}{linha['Descrição']}{linha['Valor']}"
    return hashlib.md5(string_base.encode('utf-8')).hexdigest()

def categorizar_despesas(despesas):
    # Obtemos o caminho para a tabela preenchida
    de_para_path = os.path.join(script_dir, 'Tabela_De_Para_Preenchida.xlsx')

    # Armazenamos o dataframe
    de_para_2014_2025 = pd.read_excel(de_para_path)

    # Criamos um dicionário a partir da tabela de correspondência
    de_para_2014_2025_dict = de_para_2014_2025.set_index('Descrição')['Categoria'].to_dict()

    # Criamos a coluna de categoria com base no mapeamento
    despesas['Categoria'] = despesas['Descrição'].map(de_para_2014_2025_dict)

def gerar_dict_datas(ano):
    if ano < 2016:
        return {
            'Janeiro': f'01/01/{ano}',
            'Fevereiro': f'01/02/{ano}',
            'Março': f'01/03/{ano}',
            'Abril': f'01/04/{ano}',
            'Maio': f'01/05/{ano}',
            'Junho': f'01/06/{ano}',
            'Julho': f'01/07/{ano}',
            'Agosto': f'01/08/{ano}',
            'Setembro': f'01/09/{ano}',
            'Outubro': f'01/10/{ano}',
            'Novembro': f'01/11/{ano}',
            'Dezembro': f'01/12/{ano}'
        }
    else:
        return {
            'JAN': f'01/01/{ano}',
            'FEV': f'01/02/{ano}',
            'MAR': f'01/03/{ano}',
            'ABR': f'01/04/{ano}',
            'MAI': f'01/05/{ano}',
            'JUN': f'01/06/{ano}',
            'JUL': f'01/07/{ano}',
            'AGO': f'01/08/{ano}',
            'SET': f'01/09/{ano}',
            'OUT': f'01/10/{ano}',
            'NOV': f'01/11/{ano}',
            'DEZ': f'01/12/{ano}'
        }

def extrair_2014_2015(ano):
    # Acessar a aba de 2014
    plan = planilha.worksheet(str(ano))

    # Obter os cabeçalhos da planilha de 2014
    headers = plan.row_values(1)

    # Filtrar os cabeçalhos para remover os vazios
    headers = [h for h in headers if h.strip()]

    # importar os dados da planilha de 2014 somente dos cabeçalhos válidos
    data = plan.get_all_records(expected_headers=headers)
    df = pd.DataFrame(data)

    # Criamos uma lista vazia que irá abrigar os subconjuntos criados no loop
    subsets = []

    # Criamos também um dicionário que relaciona as labels de meses do cabeçalho
    # com as datas que queremos inserir na coluna de data
    map_datas = gerar_dict_datas(ano)

    # Abrimos o loop definindo as variáveis e iremos iterar sobre os itens do dict
    for mes , data_despesa in map_datas.items():
        # Inicialmente verificamos se existe o mês do dict dentro do df de 2014
        if mes not in headers:
            continue

        # Criamos o primeiro subset selecionando a coluna de descrição e a
        # coluna do respectivo mês
        subset_df = df[[f'Despesas {ano}', mes]].copy()

        # Adicionamos a coluna de data no formato definido no dict
        subset_df['Data'] = data_despesa

        # Renomeamos as colunas para o padrão desejado
        subset_df.rename(columns={mes: 'Valor',f'Despesas {ano}':'Descrição'}, inplace=True)

        # Inserimos o subset dentro do contâiner criado anteriormente
        subsets.append(subset_df)

    # Transformamos a lista de dataframes num único dataframe para realizar
    # a limpeza dos dados
    despesas = pd.concat(subsets, ignore_index=True)

    # Vamos trocar o símbolo de decimal brasileiro para o americano
    # para consumo pela ferramenta de BI e deixamos a configuração de visualização
    # para a ferramenta de análise

    # Para a substituição primeiro convertemos os valores para string para que
    # possamos utilizar o método .replace() e depois convertemos de volta para número
    despesas['Valor'] = pd.to_numeric(
        despesas['Valor'].astype(str).str.replace(',', '.'),
        errors='coerce'
    )

    # Realizamos a limpeza da coluna valor
    despesas = despesas.dropna(subset=['Valor']) # Remove NA
    despesas = despesas[despesas['Valor'] != ''] # Remove vazios
    despesas = despesas[despesas['Valor'] != 0] # Remove zeros

    # Removemos as linhas onde temos descrição vazia
    despesas = despesas[despesas['Descrição'] != '']

    # Definimos o tipo de operação pelo sinal do valor
    despesas['Tipo'] = np.where(despesas['Valor'] < 0, 'D', 'R')

    # Convertemos de volta para valor para eliminação do sinal
    despesas['Valor'] = despesas['Valor'].astype(float).abs()

    # Categorizamos as despesas
    categorizar_despesas(despesas)

    # Criamos o id único para cada linha
    despesas['ID'] = despesas.apply(gerar_id_unico, axis=1)

    return despesas

def extrair_2016_2018(ano):
    #Importamos os dados de 2018 da planilha e criamos o DataFrame
    plan = planilha.worksheet(str(ano))
    data = plan.get_all_records(numericise_ignore=['all'])
    df = pd.DataFrame(data)

    #Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
    #coluna e então remover a coluna pois não será mais necessária
    df = df.loc[df['C'] != 'C', :].iloc[:,1:]

    #Criamos a lista e o dict de datas para criar a coluna posteriormente
    subsets = []
    map_datas = gerar_dict_datas(ano)

    #O loop faz a divisão em subsets que são armazenados em uma lista
    for mes , data_despesa in map_datas.items():
        # Verificamos se o mês do dict existe entre as colunas do df de 2018
        if mes not in df.columns:
            continue

        #Encontramos o índice da coluna para usar de referência
        i_col = df.columns.get_loc(mes)
        subset_df = df.iloc[:, (i_col - 2):i_col + 1].copy()

        #Criamos a coluna de data utilizando o dict criado anteriormente
        subset_df['Data'] = data_despesa

        #Renomeamos as colunas para padronizar com os outros anos
        subset_df.rename(
            columns={mes : 'Valor',
                    f'DESC_{mes}':'Descrição',
                    f'C_{mes}':'Código'},
                    inplace=True
                    )

        #Armazenamos o subset na lista criada anteriormente
        subsets.append(subset_df)

    #Concatenamos a lista com os subsets em um único DataFrame
    despesas = pd.concat(subsets, ignore_index=True)

    #Convertemos a coluna de valor para numérico e tratamos os erros
    despesas['Valor'] = pd.to_numeric(
        despesas['Valor'].astype(str).str.replace(',', '.'),
        errors='coerce'
    )

    # Realizamos a limpeza da coluna valor
    despesas = despesas.dropna(subset=['Valor']) # Remove NA
    despesas = despesas[despesas['Valor'] != ''] # Remove vazios
    despesas = despesas[despesas['Valor'] != 0] # Remove zeros

    # Removemos as linhas onde temos descrição vazia
    despesas = despesas[despesas['Descrição'] != '']

    #Criamos a coluna de tipo para diferenciar receitas e despesas
    despesas['Tipo'] = np.where(despesas['Código'] == 'R', 'R', 'D')

    #Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
    despesas['Tipo'] = np.where((despesas['Tipo'] == 'D') & (despesas['Valor'] > 0), 'RE', despesas['Tipo'])

    #Removemos a coluna de categoria pois não será mais necessária
    despesas = despesas.drop(columns=['Código'])

    #Transformamos os valores da coluna valor para positivos
    despesas['Valor'] = despesas['Valor'].abs()

    # Categorizamos as despesas
    categorizar_despesas(despesas)

    # Criamos o id único para cada linha
    despesas['ID'] = despesas.apply(gerar_id_unico, axis=1)

    return despesas

def extrair_2019_2025(ano):
    # Importamos os dados do ano da planilha e criamos o DataFrame
    plan = planilha.worksheet(str(ano))
    data = plan.get_all_records(numericise_ignore=['all'])
    df = pd.DataFrame(data)

    # Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
    # coluna e então remover a coluna pois não será mais necessária
    df = df.loc[df['C'] != 'C', :].iloc[:,1:]

    # Criamos a lista e o dict de datas para criar a coluna posteriormente
    subsets = []
    map_datas = gerar_dict_datas(ano)

    # O loop faz a divisão em subsets que são armazenados em uma lista
    for mes , data_despesa in map_datas.items():

        # Verificamos se o mês do dict existe entre as colunas do df do ano
        if mes not in df.columns:
            continue

        # Encontramos o índice da coluna para usar de referência
        i_col = df.columns.get_loc(mes)
        subset = df.iloc[:, (i_col - 2):i_col + 1].copy()

        # Criamos a coluna de data utilizando o dict criado anteriormente
        subset['Data'] = data_despesa

        # Renomeamos as colunas para padronizar com os outros anos
        subset.rename(
            columns={mes : 'Valor',
                    f'DESC_{mes}':'Descrição',
                    f'C_{mes}':'Código'},
                    inplace=True
                    )

        # Armazenamos o subset na lista criada anteriormente
        subsets.append(subset)

    # Concatenamos a lista com os subsets em um único DataFrame
    despesas = pd.concat(subsets, ignore_index=True)

    # Convertemos a coluna de valor para numérico e tratamos os erros
    despesas['Valor'] = pd.to_numeric(
        despesas['Valor'].astype(str).str.replace(',', '.'),
        errors='coerce'
    )

    # Realizamos a limpeza da coluna valor
    despesas = despesas.dropna(subset=['Valor']) # Remove NA
    despesas = despesas[despesas['Valor'] != ''] # Remove vazios
    despesas = despesas[despesas['Valor'] != 0] # Remove zeros

    # Realizamos a limpeza da coluna descrição
    despesas = despesas[despesas['Descrição'] != '']

    # Criamos a coluna de tipo para diferenciar receitas e despesas
    despesas['Tipo'] = np.where(despesas['Código'] == 'R', 'R', 'D')

    # Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
    despesas['Tipo'] = np.where((despesas['Tipo'] == 'D') & (despesas['Valor'] < 0), 'RE', despesas['Tipo'])

    # Removemos a coluna de categoria pois não será mais necessária
    despesas = despesas.drop(columns=['Código'])

    # Transformamos os valores da coluna valor para positivos
    despesas['Valor'] = despesas['Valor'].abs()

    # Categorizamos as despesas
    categorizar_despesas(despesas)

    # Criamos o id único para cada linha
    despesas['ID'] = despesas.apply(gerar_id_unico, axis=1)

    return despesas

def extrair_pos_2026(ano):

    # Criamos o contâiner que irá armazenar os subsets
    subsets = []
    map_datas = gerar_dict_datas(ano)

    # Importamos os dados do ano da planilha e criamos o DataFrame
    plan = planilha.worksheet(str(ano))
    data = plan.get_all_records(numericise_ignore=['all'])
    raw = pd.DataFrame(data)

    # Vamos filtrar as linhas marcadas como cabeçalho utilizando a primeira
    # coluna e então remover a coluna pois não será mais necessária
    raw = raw.loc[raw['C'] != 'C', :].iloc[:,1:]

    # O loop faz a divisão em subsets que são armazenados em uma lista
    for mes , data_despesa in map_datas.items():

        # Encontramos o índice da coluna para usar de referência
        i_col = raw.columns.get_loc(mes)
        subset_df = raw.iloc[:, (i_col - 3):i_col + 1].copy()

        # Criamos a coluna de data utilizando o dict criado anteriormente
        subset_df['Data'] = data_despesa

        # Renomeamos as colunas para padronizar com os outros anos
        subset_df.rename(
            columns={mes : 'Valor',
                    f'DESC_{mes}':'Descrição',
                    f'C_{mes}':'Código',
                    f'CAT_{mes}':'Categoria'
                    },
                        inplace=True
                        )
        # Armazenamos o subset na lista criada anteriormente
        subsets.append(subset_df)

    # Concatenamos a lista com os subsets em um único DataFrame
    despesas = pd.concat(subsets, ignore_index=True)

    # Convertemos a coluna de valor para numérico e tratamos os erros
    despesas['Valor'] = pd.to_numeric(
        despesas['Valor'].astype(str).str.replace(',', '.'),
        errors='coerce'
    )

    # Realizamos a limpeza da coluna valor
    despesas = despesas.dropna(subset=['Valor']) # Remove NA
    despesas = despesas[despesas['Valor'] != ''] # Remove vazios
    despesas = despesas[despesas['Valor'] != 0] # Remove zeros

    # Realizamos a limpeza da coluna descrição
    despesas = despesas[despesas['Descrição'] != '']

    # Criamos a coluna de tipo para diferenciar receitas e despesas
    despesas['Tipo'] = np.where(despesas['Código'] == 'R', 'R', 'D')

    # Valores positivos com código de despesa 'D' são classificados como 'RE' (Reembolso)
    despesas['Tipo'] = np.where((despesas['Tipo'] == 'D') & (despesas['Valor'] < 0), 'RE', despesas['Tipo'])

    # Removemos a coluna de código pois não será mais necessária
    despesas = despesas.drop(columns=['Código'])

    # Transformamos os valores da coluna valor para positivos
    despesas['Valor'] = despesas['Valor'].abs()

    # Criamos o id único para cada linha
    despesas['ID'] = despesas.apply(gerar_id_unico, axis=1)

    return despesas

def extrair_despesas_ano(ano):
    if ano < 2016:
        return extrair_2014_2015(ano)
    elif ano < 2019:
        return extrair_2016_2018(ano)
    elif ano < 2026:
        return extrair_2019_2025(ano)
    else:
        return extrair_pos_2026(ano)

# %% [markdown]
# ## Armazenamento e atualização do histórico
#
# Para economizar processamento, assumimos que os dados do passado são estáticos e precisamos atualizar apenas os dados do ano corrente periodicamente, com os dados do ano anterior sendo acrescentados ao histórico. Para isso precisamos:
#
# * Verificar qual o último ano fiscal armazenado no histórico
# * Comparar o ano fiscal anterior com o último do histórico
#   * Se não armazenado, realizar o registro no histórico
#   * Se já armazenado, seguir com a extração do ano atual
# * Realizar o tratamento dos dados do ano atual
#
# Vamos salvar o histórico já categorizado como um arquivo CSV separado para que seja consultado com o Dashboard e possamos economizar processamento rodando apenas a importação do ano atual.

# %%
hist_path = os.path.join(script_dir, 'despesas_2014_a_2025.csv')

despesas_ant_2025.to_csv(hist_path,
                         index=False,
                         sep = ';',
                         decimal = '.')

# %% [markdown]
# A seguir vamos criar funções que irão definir a data inicial do ano fiscal em relação a data de corte pré-determinada, o último ano armazenado no histórico e por fim a data atual para que a função que verifica o status do histórico possa ser melhor interpretada.

# %%
def ultima_data_historico():
    # Obtemos o caminho para a tabela preenchida
    hist_path = os.path.join(script_dir, 'despesas_2014_a_2025.csv')
    # Lemos o arquivo CSV para obter a última data presente no histórico
    historico = pd.read_csv(hist_path, sep=';', decimal='.')
    # Retornamos a última data presente no histórico convertida para o formato date
    return date(int(historico['Data'].max().split('/')[2]),
                int(historico['Data'].max().split('/')[1]),
                int(historico['Data'].max().split('/')[0]))

def inicio_fiscal_atual():
    # Verificamos se a data atual é entre 1 e 10 de janeiro para definir o início fiscal
    if date.today() < date(date.today().year, 1, 10) and date.today() > date(date.today().year, 1, 1):
        # Se estivermos antes do dia 10, retornamos o início fiscal do ano anterior
        return date(date.today().year - 1, 1, 10)
    else:
        # Caso contrário, retornamos o início fiscal do ano atual
        return date(date.today().year, 1, 10)

def data_atual():
    # Função apenas para deixar o código melhor interpretável, retorna a data atual
    return date.today()

# %% [markdown]
# Com isso podemos elaborar uma função que sempre que ocorrer uma nova extração de dados da planilha seja feita uma verificação da atualização do histórico.
#
# Essa atualização irá verificar qual a última data do histórico e cruzar com a data do ano fiscal atual para se determinar a necessidade de complemento do histórico com base na seguinte lógica:
#
# 1. Subtrair o ano da última data do histórico com o ano fiscal atual:
#     * Caso o resultado seja maior ou igual a 2, significa que o ano fiscal anterior não está no histórico
#     * Esse cenário é esperado na primeira execução do script após a virada do ano fiscal (No momento, o dia 10/jan daquele ano)
#     * Caso o resultado seja positivo, iremos realizar a extração dos dados do ano fiscal anterior e atualizamos o histórico
# 2. Extrair os dados do ano atual e tratá-los para consumo pelo Dashboard

# %%
if inicio_fiscal_atual().year - ultima_data_historico().year >= 2:
    despesas_ano_anterior = extrair_despesas_ano(inicio_fiscal_atual().year - 1)
    # Criar função que importa o histórico
    # Adiciona o df ao CSV do histórico
elif ultima_data_historico().year == date.today().year - 1:
    print(f'O histórico de despesas está desatualizado. O último ano fiscal presente é {ultima_data_historico().year}.')
# Out:
# O histórico de despesas está desatualizado. O último ano fiscal presente é 2025.

# %%
def conv_mongo(despesas):
    # Convertemos o DataFrame para um formato de dicionário adequado para MongoDB
    return despesas.to_dict(orient='records')

conv_mongo(extrair_2016_2018(2016))
# Out:
# e:\Python\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# [{'Descrição': 'JV - Quinto dia',
#   'Valor': 1560.0,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '89024ffbcc3fc43accf8614a3b541595'},
#  {'Descrição': 'JV - Adiantamento',
#   'Valor': 1351.91,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '51c999699b6caf357c9aa9a096580eb3'},
#  {'Descrição': 'Ajuste',
#   'Valor': 1881.24,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Financeiro',
#   'ID': 'a6d5e440e66b2b2f787a92f425c06dc7'},
#  {'Descrição': 'Adiantamento mês seguinte',
#   'Valor': 1352.0,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '70d414b0fb07c886e9d0d569f1568179'},
#  {'Descrição': 'Vale João',
#   'Valor': 379.0,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': 'ac98a319b13d731d863f36ba7c05be7d'},
#  {'Descrição': 'Vale Marilia',
#   'Valor': 70.0,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '50a6ec9671da02601aa322e3ade487e6'},
#  {'Descrição': 'Marilia - Quinto dia',
#   'Valor': 127.0,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '20999848163d1ce8827b82b1cd3da3b4'},
#  {'Descrição': 'Marilia - Adiantamento',
#   'Valor': 473.0,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': 'de4c3ee94cb2d2d9719b821663e54808'},
#  {'Descrição': 'Aluguel',
#   'Valor': 1200.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'fbd39b7f92d2769561c15d574a87fa78'},
#  {'Descrição': 'Condomínio',
#   'Valor': 335.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'd403fa11581a9feefc7d331ea90e8306'},
#  {'Descrição': 'Taiko',
#   'Valor': 80.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'c4fd1698331570ba2becf2ed1c85f77e'},
#  {'Descrição': 'Eletropaulo',
#   'Valor': 120.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '402d9eaf72c803a19d05fc8782bc33a8'},
#  {'Descrição': 'Vivo Fixo',
#   'Valor': 113.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '28228bc73986d32e4aec391bc9d002fa'},
#  {'Descrição': 'Vivo Fibra',
#   'Valor': 69.83,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '2655c31bb325f57d42e0ea54a124e509'},
#  {'Descrição': 'Gás ',
#   'Valor': 7.83,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '39197587cc9586e4520192a1a52f662e'},
#  {'Descrição': 'Netflix',
#   'Valor': 20.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'bfb622c22faf689444bf0bf6c27a09f5'},
#  {'Descrição': 'Ônibus JV',
#   'Valor': 100.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '3c8451bb7f918e1bae54407297d618ba'},
#  {'Descrição': 'Seguro de vida',
#   'Valor': 88.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Saúde',
#   'ID': '437fb18ecd701bb607e6904e1f196590'},
#  {'Descrição': 'Poupança',
#   'Valor': 270.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Investimentos e Poupança',
#   'ID': '17474cb23bd2507cbdf8827cfcaef837'},
#  {'Descrição': 'Vivo Celulares',
#   'Valor': 237.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'd27ec39252a234c34727237fac4ffd26'},
#  {'Descrição': 'Gatos',
#   'Valor': 81.94,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Pets',
#   'ID': '4360ccc2c8e042040f924bd747f01e99'},
#  {'Descrição': 'Empréstimo mamãe',
#   'Valor': 400.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '6bf03d729a955a731007ae0700cfb9f2'},
#  {'Descrição': 'Anuidade diferenciada 4/12',
#   'Valor': 22.99,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'da71c5ef9db588bc900466eca66660d0'},
#  {'Descrição': 'Anuidade diferenciada 5/12',
#   'Valor': 18.32,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '56273cfdb304536223e5c36be829077d'},
#  {'Descrição': 'Momoi - Anuidade Marilia',
#   'Valor': 12.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '4b138825216e0d5f2b1bc6bf19a8010c'},
#  {'Descrição': 'Nikon 10x',
#   'Valor': 50.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'dc2eb9c39eebc87af5e12aa72ab98b6f'},
#  {'Descrição': 'Momoi - Bikini 10/12',
#   'Valor': 18.3,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'fcf74620faef542628ce95ba84cab00b'},
#  {'Descrição': 'Momoi - Google music',
#   'Valor': 12.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '3e5ce9686526ce7055002ba60cf02c29'},
#  {'Descrição': 'Momoi - Sei la',
#   'Valor': 29.7,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'b10494dbff41a33c7fb7a1602d7daaca'},
#  {'Descrição': 'Naruto 3/6',
#   'Valor': 29.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '6ac723e721599316dadd74d03e61e6f6'},
#  {'Descrição': 'Tênis 3/3',
#   'Valor': 57.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'a4d5571f3b63c384246a36695a277675'},
#  {'Descrição': 'Bikini 3/5',
#   'Valor': 36.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'a6edae60c155e6f19a2b57c4f5e05af4'},
#  {'Descrição': 'Chromecast 2/3',
#   'Valor': 57.86,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': 'ecb90a40ad30dab8951cd0c063c9a94d'},
#  {'Descrição': 'Roupas Marisa 2/2',
#   'Valor': 52.97,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'affeebff557b6b9da1a88ded0b4a7cb3'},
#  {'Descrição': 'Yoshida Brothers',
#   'Valor': 94.4,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '29927cb3e78548828100fd3a92bc9d08'},
#  {'Descrição': 'X',
#   'Valor': 29.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': 'b82f67cdedb76c07baa968576baa51d8'},
#  {'Descrição': 'X',
#   'Valor': 4.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': 'eb3b81e36a2fc265de41faa422bcc10a'},
#  {'Descrição': 'X',
#   'Valor': 18.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': 'ee4c9e6ad8cb75b63a25382495ecacce'},
#  {'Descrição': 'X',
#   'Valor': 37.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '7e00ba43476c60bc9a5b5536ce983cca'},
#  {'Descrição': 'X',
#   'Valor': 38.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '18b87b1332b3b0bb2477fc676b0e88bc'},
#  {'Descrição': 'X',
#   'Valor': 28.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '7749361d179cb08c443f2836a8de5d37'},
#  {'Descrição': 'X',
#   'Valor': 18.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': 'ee4c9e6ad8cb75b63a25382495ecacce'},
#  {'Descrição': 'X',
#   'Valor': 15.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '02d14417691dfd644b012adcae6bef56'},
#  {'Descrição': 'Amigo secreto Marilia',
#   'Valor': 26.98,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '00aaf02d2e6bc39e39537b2ca546b604'},
#  {'Descrição': 'Parafusos Noren',
#   'Valor': 6.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '27da1bcd27b0b09bfa7d436534387fd9'},
#  {'Descrição': 'Frango assado Guarujá',
#   'Valor': 39.7,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '91963cb8dd2f08a6aa84eb1eb3c42f7f'},
#  {'Descrição': 'Mercado Guarujá',
#   'Valor': 27.99,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '05c2c571d78b5074f2658f600ff1f68f'},
#  {'Descrição': 'Sorvete Guarujá',
#   'Valor': 39.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '7bc806f621097d40fb3ec652fa7f087e'},
#  {'Descrição': 'Esfiha imigrantes',
#   'Valor': 33.66,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '5a6f9dfc199d39e71a9bee23efad890f'},
#  {'Descrição': 'Ikesaki',
#   'Valor': 47.95,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '04035c49091d5300b77efcc5d7b8dfd7'},
#  {'Descrição': 'Marukai',
#   'Valor': 53.1,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '3ea348a87d394842a0029fe2f910887d'},
#  {'Descrição': 'Noren',
#   'Valor': 150.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '688ef9c181551f7d0e622f7690c98ae4'},
#  {'Descrição': 'Porque sim',
#   'Valor': 26.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'ba7766a7816ec3f47813f2ffbac3a541'},
#  {'Descrição': 'Dremel',
#   'Valor': 40.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '974232af8c32b350e5bbdad1570ac0bc'},
#  {'Descrição': 'Parc CC 1/6',
#   'Valor': 541.92,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '79c90a3a75695e31db639b0fa913ffc6'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 36.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '5785060bf603f115bb060cfe2de3af43'},
#  {'Descrição': 'Taxi 12/12',
#   'Valor': 14.5,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '09e3b8d1ec55a64850bfdb9b77861197'},
#  {'Descrição': 'Taxi Alberta',
#   'Valor': 57.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '323fc8be01b931ee31d1f4ea4b9d1f05'},
#  {'Descrição': 'Taxi momoi 5/12',
#   'Valor': 14.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'c4cd12dc995462fa54f4d686db61079e'},
#  {'Descrição': 'Alberta',
#   'Valor': 95.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'e8fedda0aab26799fe709c5a01497146'},
#  {'Descrição': 'Orange 2',
#   'Valor': 14.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'ad4b980520e5c543b2feaa315dfd0f5d'},
#  {'Descrição': 'Taxi',
#   'Valor': 12.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '28a52a874344ad51df9434348fc78e5a'},
#  {'Descrição': 'Tokyo Ghoul 3',
#   'Valor': 12.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '8d0d9e85982c62aa6786475237314c68'},
#  {'Descrição': 'Coquinha momoi',
#   'Valor': 9.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '37791fd5fe1e924a0ae90db285c9286e'},
#  {'Descrição': 'Porque sim Bounenkai',
#   'Valor': 34.1,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '03397fc5e7e5745d9e91dd01b58dfba2'},
#  {'Descrição': 'Daiso Nihongo',
#   'Valor': 6.99,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': 'f8982e20644b6e3fd5501661b4109aed'},
#  {'Descrição': 'Pão',
#   'Valor': 7.54,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '880673debc875ae6f056555ce1dbe40a'},
#  {'Descrição': 'Cerveja',
#   'Valor': 44.7,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '9294dfe9c626cac86e3aee362e5fd67d'},
#  {'Descrição': 'Prime Dog Bel',
#   'Valor': 12.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Pets',
#   'ID': '980171f538573a6f5d21e8adacb1fa7d'},
#  {'Descrição': 'Star Wars',
#   'Valor': 25.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '864cf986c57308bd6c52a997c72d06df'},
#  {'Descrição': 'Chobits 8',
#   'Valor': 16.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '3e7c779faecce727d809775ee7ca8824'},
#  {'Descrição': 'Tylenol Sinus',
#   'Valor': 13.97,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '264aa24ec7459c3c26db74dc2f2a344f'},
#  {'Descrição': 'Tylenol Sinus',
#   'Valor': 13.97,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '264aa24ec7459c3c26db74dc2f2a344f'},
#  {'Descrição': 'KFC Cineminha',
#   'Valor': 49.4,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'c14ee5703fa1af71377870a7ea532117'},
#  {'Descrição': 'Pão',
#   'Valor': 7.41,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '40e3d49dca18e05ec97ebe102333298e'},
#  {'Descrição': 'Pizza',
#   'Valor': 39.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '10ea14827b1e9d4fa874fab10c787bda'},
#  {'Descrição': 'Pão',
#   'Valor': 2.96,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '2c83b30f424f3a5b3224f8f67e82c1a2'},
#  {'Descrição': 'Pão',
#   'Valor': 9.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '81b487a9f02a7dfae19e7d2432646dd0'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 22.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'c1e63b0dfe49b87b90fef35bf4aa59fc'},
#  {'Descrição': 'Amigo secreto Mãe',
#   'Valor': 40.98,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '0af0dbca4c209fc3727afe994f5fd05e'},
#  {'Descrição': 'Bolo verde',
#   'Valor': 12.01,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'a82b8affbfb33666d2199fd21dca096a'},
#  {'Descrição': 'Aquecedor momoi',
#   'Valor': 87.7,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '7becfb6d343c3a0dac69dc679718d1a3'},
#  {'Descrição': 'Café da manhã Pedro',
#   'Valor': 36.63,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'fb32175199992a45f9a8853e3de49bff'},
#  {'Descrição': 'Pizza Pedro',
#   'Valor': 32.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b5b07879a845a558b44b42228e2571f8'},
#  {'Descrição': 'Peruca',
#   'Valor': 40.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '62353e1579a68e6ef0035ae3600bf647'},
#  {'Descrição': 'Compras Marilia',
#   'Valor': 38.1,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '95c5a032ccc634083ed2c03bb2a348f1'},
#  {'Descrição': 'Compras Marilia',
#   'Valor': 36.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '356683d0faa18e511900876ddb7ca5ab'},
#  {'Descrição': 'Compras Marilia',
#   'Valor': 11.98,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '6f95f73803e36445bd71d2312094269a'},
#  {'Descrição': 'Taxi',
#   'Valor': 22.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'cdacac3a8cf7521c9d20ceff5ece77f3'},
#  {'Descrição': 'Doces Marilia',
#   'Valor': 19.4,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'c314bbcb12b22175b78934718f72f6fe'},
#  {'Descrição': 'Marilia no shops',
#   'Valor': 111.95,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'a5f15a460ee5999a524b63290ac851c9'},
#  {'Descrição': 'Taxi',
#   'Valor': 25.3,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'c7e4940ae9bc8960bc4f5ece12701400'},
#  {'Descrição': 'Almoço Marilia',
#   'Valor': 13.61,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'f60acd339f49a2848a2039acba97f492'},
#  {'Descrição': 'Doces Marilia',
#   'Valor': 9.8,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '273b059b22178ecbbc796e8c482cb3f9'},
#  {'Descrição': 'Rocket League',
#   'Valor': 20.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '2c2c99a45565086b1c4e0ef26243ad2c'},
#  {'Descrição': 'CC 12/12',
#   'Valor': 127.09,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '4739a3b78daf28a17e290d6df544890d'},
#  {'Descrição': 'IOF',
#   'Valor': 4.18,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '7fdb3dad942b6040b0518768e827dbd7'},
#  {'Descrição': 'Seguro',
#   'Valor': 6.99,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Veículo',
#   'ID': '221c951b25f2ff345cbdea6c7556f4c9'},
#  {'Descrição': 'Acerto CC',
#   'Valor': 242.33,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'ef008b727e8b7785fb33b47bbbe4cd28'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 16.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '76ae630193827d93883939f0dd456fb1'},
#  {'Descrição': 'Suco Marilia',
#   'Valor': 6.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'abccadc0b58e0659065912c91a9f02af'},
#  {'Descrição': 'Sobrancelha Marilia',
#   'Valor': 35.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'd62c482541783466f320a26c72df7ad7'},
#  {'Descrição': 'Orange 3',
#   'Valor': 14.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '9f891f910e896148a62ea33f15ec630d'},
#  {'Descrição': 'Taxi 7/1/16',
#   'Valor': 21.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '967a2d39f84774d6abb6d15a1fa93257'},
#  {'Descrição': 'Taxi 5/1/16',
#   'Valor': 22.5,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '66225e5b79a15e2a366325876a1e7eb2'},
#  {'Descrição': 'Encargos',
#   'Valor': 8.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '9b700a09d111b4df520dd634e477b97c'},
#  {'Descrição': 'Ultraman 3',
#   'Valor': 14.9,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '8a3ba5dfa82444ceab9bea9cd9a67f0b'},
#  {'Descrição': 'Daiso',
#   'Valor': 40.04,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '4c2df62193970618dbe604aeabad890d'},
#  {'Descrição': 'Caixe de limpeza',
#   'Valor': 50.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '927e2c1f4c08d6bbc5b6be1c70234e18'},
#  {'Descrição': 'Taxi 11/1/16',
#   'Valor': 23.1,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '580233f34e4c8b87804309443fcf0949'},
#  {'Descrição': 'Taxi',
#   'Valor': 22.5,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0cababf9c2df5b3d8ab16a237ee20555'},
#  {'Descrição': 'Acerto cc',
#   'Valor': 37.1,
#   'Data': '01/01/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Financeiro',
#   'ID': 'bc5306b15fb348b6c4c388eebd5d4447'},
#  {'Descrição': 'McDonalds',
#   'Valor': 22.0,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '201d24ded8cfe4393ad8b3d16a392562'},
#  {'Descrição': 'Amor aos pedaços',
#   'Valor': 16.36,
#   'Data': '01/01/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '6d42568e0aaa1094a00c0168c32db4f0'},
#  {'Descrição': 'JV - Quinto dia',
#   'Valor': 1560.0,
#   'Data': '01/02/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': 'd0dcb2eaa07a6d5b9e4317cfc99b7a7a'},
#  {'Descrição': 'JV - Adiantamento',
#   'Valor': 0.09,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Receitas',
#   'ID': '9100e5aa55d14ea68660bfd5d7aa80c3'},
#  {'Descrição': 'Adiantamento mês seguinte',
#   'Valor': 1352.0,
#   'Data': '01/02/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': 'f2fee779a2074f093621a45f53c7ee08'},
#  {'Descrição': 'Vale João',
#   'Valor': 405.0,
#   'Data': '01/02/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '38d2e51151aa276d0cb82835925b7d04'},
#  {'Descrição': 'Marilia - Quinto dia',
#   'Valor': 114.0,
#   'Data': '01/02/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '1329a6dc566d7fb3f403df1e330db30f'},
#  {'Descrição': 'Marilia - Adiantamento',
#   'Valor': 946.0,
#   'Data': '01/02/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '58e8d1c1806c2cfe57abd1ba4141e300'},
#  {'Descrição': 'Aluguel',
#   'Valor': 1200.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'd6f66366ba8fcb69ccdd5acaea3a9b50'},
#  {'Descrição': 'Condomínio',
#   'Valor': 304.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '106b8c1414e4e07da67cf195e51f206d'},
#  {'Descrição': 'Diarista 1',
#   'Valor': 100.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '1246ee38d8cb4573cb9b78133461dee6'},
#  {'Descrição': 'Diarista 2',
#   'Valor': 100.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '2e20b95b1b9cfac8eb25a428d21853c4'},
#  {'Descrição': 'Taiko',
#   'Valor': 80.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'f34455e5e58cff1733ae7af2cc7ec1b4'},
#  {'Descrição': 'Eletropaulo',
#   'Valor': 81.65,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'a2d78b8e032d5ae75b4c7ae907b02e3c'},
#  {'Descrição': 'Vivo Fixo',
#   'Valor': 113.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'efbf293105e81015ffe91e23fa647b08'},
#  {'Descrição': 'Vivo Fibra',
#   'Valor': 70.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '77b065a2d73d3e63202cb1837a8b0702'},
#  {'Descrição': 'Gás ',
#   'Valor': 3.91,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'b86c98261bf58d0907e82eb27dc33320'},
#  {'Descrição': 'Netflix',
#   'Valor': 20.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'dcec902087b0698302423d485bbd8568'},
#  {'Descrição': 'Ônibus JV',
#   'Valor': 140.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '67c50fb192452b689d4020617faa2f58'},
#  {'Descrição': 'Seguro de vida',
#   'Valor': 88.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Saúde',
#   'ID': 'e7773c57b795b2f54380133f0bc30a7c'},
#  {'Descrição': 'Vivo Celulares',
#   'Valor': 242.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '7f755006db2cf20220442de2bd4af707'},
#  {'Descrição': 'Amor doce',
#   'Valor': 331.58,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '4180a4c3b5c1e1c971df3de8a11391d6'},
#  {'Descrição': 'Gatos',
#   'Valor': 267.94,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Pets',
#   'ID': '1ac20af75cf9f8e24311643e3eb07f3e'},
#  {'Descrição': 'Empréstimo mamãe',
#   'Valor': 257.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'c3201ae44dcd62ee394c29eafd828b06'},
#  {'Descrição': 'Anuidade diferenciada 5/12',
#   'Valor': 22.99,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '7197035f9dbb81509a11d76724381558'},
#  {'Descrição': 'Anuidade diferenciada 6/12',
#   'Valor': 18.32,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'd8c22a370adbd148d5d43007eddd9e91'},
#  {'Descrição': 'Momoi - Anuidade Marilia',
#   'Valor': 12.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '595f179473896a911e18b07e0e1f12bf'},
#  {'Descrição': 'Nikon 10x',
#   'Valor': 50.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '3178e7ccd25f4b6f854fab099738f7a1'},
#  {'Descrição': 'Momoi - Bikini 11/12',
#   'Valor': 18.3,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'f917445c76a0918b602e403c8f2b3e93'},
#  {'Descrição': 'Momoi - Google music',
#   'Valor': 12.9,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '561cfbb75686c1c1963eca58b443c7ca'},
#  {'Descrição': 'Naruto 4/6',
#   'Valor': 29.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '77a81d2ed1c0430c4eaa655e0ae25378'},
#  {'Descrição': 'Bikini 4/5',
#   'Valor': 36.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '9193158ec4579d85e4525a997be95433'},
#  {'Descrição': 'Chromecast 3/3',
#   'Valor': 57.86,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '1fb847c3bc7d0babc16b16d4b60ca203'},
#  {'Descrição': 'Parc CC 2/6',
#   'Valor': 541.92,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '34049f1faceb29a8cb96083ab09bfb91'},
#  {'Descrição': 'Remédio do peixe 1/3',
#   'Valor': 22.38,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Pets',
#   'ID': 'a489cba41499edf0cb1b25724b4d9ec9'},
#  {'Descrição': 'Papers please',
#   'Valor': 7.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'cce8bb4bb1935519cf3e47a89881c5ee'},
#  {'Descrição': 'Taxi',
#   'Valor': 24.1,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'a22988fd26ce54ff0cac5dd06e6e4c44'},
#  {'Descrição': 'Taxi',
#   'Valor': 22.9,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0659a125e4e199e8efd8dfec2bb0e48a'},
#  {'Descrição': 'Cinema momoi',
#   'Valor': 60.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '6528ae31077dfc8fabee6d8717074fe2'},
#  {'Descrição': 'Taxi',
#   'Valor': 18.5,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0064ce15032aeb795348bae8bdc7d8e8'},
#  {'Descrição': 'Amor doce',
#   'Valor': 9.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '134eca7fd5d55196b97c2118b85def93'},
#  {'Descrição': 'Taxi 13/01/2016',
#   'Valor': 18.1,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '762802fd0da772c67edd340cd9f76e37'},
#  {'Descrição': 'Taxi 14/01/2016',
#   'Valor': 27.7,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0d944eba420639d76360820f5b070afc'},
#  {'Descrição': '8 odiados',
#   'Valor': 30.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'c13cc42f6048590918a32ebf650ba073'},
#  {'Descrição': 'McDonalds',
#   'Valor': 29.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '1f2f9746d0082c0e51fd56d34d9b2ea1'},
#  {'Descrição': 'Uber 18/01/2016',
#   'Valor': 16.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '607f6a7a8e74b3a03c52227f2c6bdeca'},
#  {'Descrição': 'Uber 19/01/2016',
#   'Valor': 28.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'ca0de5023a75552e197fdf9754c66bcd'},
#  {'Descrição': 'Café da manhã 20/01/2016',
#   'Valor': 6.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '840717b939c7f4340d225270a65079b8'},
#  {'Descrição': 'Almoço Marilia 21/01/2016',
#   'Valor': 28.86,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b289b43a5efeeee1fccd58e3212d70ae'},
#  {'Descrição': 'Uber 21/01/2016',
#   'Valor': 31.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0e8c6805a451f1f22087a2f1c73ffdf4'},
#  {'Descrição': 'Jaber',
#   'Valor': 13.8,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'd69d2feb6bff5ca181ab146589778a52'},
#  {'Descrição': 'Doces',
#   'Valor': 12.2,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '50de3f9ca88770183178bc0a9587a365'},
#  {'Descrição': 'Panetone',
#   'Valor': 11.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '3ec1bb21c7ab5bc67f8d7010a51d58bf'},
#  {'Descrição': 'Sei la',
#   'Valor': 2.37,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '7fbae2d5fa22334627962bff94a67c4b'},
#  {'Descrição': 'Pizza',
#   'Valor': 40.9,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '5891d83593d29a9c08fc864bbc412d63'},
#  {'Descrição': 'Café da manhã 26/01/2016',
#   'Valor': 16.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'fc166f43481dc30f7fd3793b035fba81'},
#  {'Descrição': 'Produtos de limpeza',
#   'Valor': 34.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '6bd28b979ef9f955459671eb6f79b8dc'},
#  {'Descrição': 'UpABC',
#   'Valor': 55.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '3fa4ddd5813b6bd5a9f7d0c504dfab17'},
#  {'Descrição': 'Pastel',
#   'Valor': 9.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'c1fc99c4519c4fe99b0bf67485c8a079'},
#  {'Descrição': 'Extra',
#   'Valor': 88.39,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'd5a1d34581c6551a80d92c76f1309416'},
#  {'Descrição': 'Taxi 28/01/2016',
#   'Valor': 24.0,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'fa8a7a12d8df30c4d00b0a121b792a68'},
#  {'Descrição': 'Ajuste Marilia',
#   'Valor': 41.02,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '64031783951f71d283982b6ed113d587'},
#  {'Descrição': 'Bilhete único',
#   'Valor': 26.6,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0fba9dd7224e7bcd406843f0ae8518e3'},
#  {'Descrição': 'Padaria',
#   'Valor': 12.3,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '70c63ac982e2b0c5a4c5f722a45fd79e'},
#  {'Descrição': 'Padaria',
#   'Valor': 1.75,
#   'Data': '01/02/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '311b2396dee8f44228e722a0bbe7715d'},
#  {'Descrição': 'Empréstimo poupança',
#   'Valor': 326.68,
#   'Data': '01/02/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Financeiro',
#   'ID': '1876c4454228a484fdc1ece7346afff7'},
#  {'Descrição': 'JV - Quinto dia',
#   'Valor': 1560.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': 'c604b5d668dfbe4ab5c615c0251c9ba9'},
#  {'Descrição': 'JV - Adiantamento',
#   'Valor': 0.09,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Receitas',
#   'ID': 'e04951f2b145ba653e5353cc3fc5ee40'},
#  {'Descrição': 'Adiantamento mês seguinte',
#   'Valor': 1352.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '7509508d75048becded1d69a03079ce0'},
#  {'Descrição': 'Vale João',
#   'Valor': 320.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '1157399e14e21223c0a5af2187499a2d'},
#  {'Descrição': 'Vale Marilia',
#   'Valor': 522.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': 'f4c94cc6e436ce3eb32a9088b080138b'},
#  {'Descrição': 'Marilia - Quinto dia',
#   'Valor': 1004.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': 'eeb04c335ef61703df7c8f9f0a210f1c'},
#  {'Descrição': 'Aluguel',
#   'Valor': 1200.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'e04527c4f6ce41dc59e62baf459200b8'},
#  {'Descrição': 'Condomínio',
#   'Valor': 309.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '5eb28d6bab8e6ddca569b3dc6fafcad0'},
#  {'Descrição': 'Diarista 1',
#   'Valor': 103.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '962ddb039e2d417edee31dfb1e74aa75'},
#  {'Descrição': 'Diarista 2',
#   'Valor': 83.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '9f83028108d9dda611bb6704453e674c'},
#  {'Descrição': 'Taiko',
#   'Valor': 80.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '3f8ad18d4f6ba93f702d3c08a400eefb'},
#  {'Descrição': 'Emp. sep cont',
#   'Valor': 1500.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Financeiro',
#   'ID': '402161d20b5738f734c7d62d558bde26'},
#  {'Descrição': 'Eletropaulo',
#   'Valor': 82.72,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '12b62226f607cd54a4ab61faf5cc168d'},
#  {'Descrição': 'Vivo Fixo',
#   'Valor': 113.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '4fe625e9f4e95e5d07d1797c4cbc2741'},
#  {'Descrição': 'Vivo Fibra',
#   'Valor': 70.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '19d3a07f94cbadde905791e7d46944cd'},
#  {'Descrição': 'Gás ',
#   'Valor': 10.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'ce90833b7384b2326f11be26fc35e306'},
#  {'Descrição': 'Netflix',
#   'Valor': 20.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '9b1718344c2e4b5ec15add1a65d6e91e'},
#  {'Descrição': 'Ônibus JV',
#   'Valor': 100.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'db4b290de62208f9bf0133ae5824f5f2'},
#  {'Descrição': 'Seguro de vida',
#   'Valor': 88.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Saúde',
#   'ID': '7a80c1ec7e5dbb7a3f9cbb882db65d0a'},
#  {'Descrição': 'Vivo Celulares',
#   'Valor': 242.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': '271245c5895f2b263cbe1c759cfc1891'},
#  {'Descrição': 'Amor doce',
#   'Valor': 50.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'b6f4e594e262e80eb14993ba2d1e2a6a'},
#  {'Descrição': 'Empréstimo mamãe',
#   'Valor': 400.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '54e3e3af1145864fabe1c6ff387fad30'},
#  {'Descrição': 'Anuidade diferenciada 6/12',
#   'Valor': 22.99,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '7b02172dbd49942ee722ab0e616f1937'},
#  {'Descrição': 'Anuidade diferenciada 7/12',
#   'Valor': 18.32,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'e6c95432d206ea653f71af5d1051c01f'},
#  {'Descrição': 'Momoi - Anuidade Marilia',
#   'Valor': 12.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'ef325b9321d59869034ba2a42dc94cba'},
#  {'Descrição': 'Nikon 10x',
#   'Valor': 50.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'ceebc03e2d39545592c625bf7f6c4d30'},
#  {'Descrição': 'Momoi - Bikini 12/12',
#   'Valor': 18.3,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'e0c38ef7f11551be0fa8a6221a2503fa'},
#  {'Descrição': 'Momoi - Google music',
#   'Valor': 12.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '2f7058b18a0145f10dc8e8b5cd89bf52'},
#  {'Descrição': 'Naruto 5/6',
#   'Valor': 29.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '8b0135d2ad03e41b0689ff31501e028e'},
#  {'Descrição': 'Bikini 5/5',
#   'Valor': 36.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'ff88d46cbf4fce8ad780fe995a2388be'},
#  {'Descrição': 'Parc CC 3/6',
#   'Valor': 541.92,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '4fb1cfaf7d9f49a202a5387db2212550'},
#  {'Descrição': 'Remédio do peixe 2/3',
#   'Valor': 22.38,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Pets',
#   'ID': '6f93b594451fab93979212b8f695db84'},
#  {'Descrição': 'Fate Stay Night',
#   'Valor': 12.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'ff69fea1bb189fcdcf0c41111dd39d50'},
#  {'Descrição': 'Comida',
#   'Valor': 25.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '6a5984df1c0f9b619ca1ce93bbf69736'},
#  {'Descrição': 'Mordecai',
#   'Valor': 20.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '13367d52b08fe215fa4b7f603059e86d'},
#  {'Descrição': 'Feitiços',
#   'Valor': 20.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '00c6d6dea4f1d253d4fa3cfdb67f9dd5'},
#  {'Descrição': 'Raspadinha',
#   'Valor': 8.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'c900553a221a983c88271cbabb0447c5'},
#  {'Descrição': 'Água',
#   'Valor': 12.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Essenciais',
#   'ID': 'cff3e66ea34bfa99afafae89caaed2b1'},
#  {'Descrição': 'Uber 31/01/2016',
#   'Valor': 21.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '391cb5d51f1f4c3d38ce489ce631eb52'},
#  {'Descrição': 'Vassoura Daiso',
#   'Valor': 14.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '6f14cea93a73a13bcc1589623c1acf8f'},
#  {'Descrição': 'Ikesaki',
#   'Valor': 17.8,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '54a06c43f24418c482d0d40a2f8b8200'},
#  {'Descrição': 'Uber 30/1/2016',
#   'Valor': 22.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '9bf63e8a9188ecec280c87a094ea4fa4'},
#  {'Descrição': 'EVA Cosplay',
#   'Valor': 14.6,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '35b0191bc2e468157ed251aa67daeb89'},
#  {'Descrição': 'Café da manha',
#   'Valor': 7.8,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '23455ed7b4d77b6f0c00c94435d7064e'},
#  {'Descrição': 'Táxi 2/1/16',
#   'Valor': 25.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'aa99b926c60b40596bca38290588cebb'},
#  {'Descrição': 'Livro Marilia',
#   'Valor': 16.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '7ccfd9c76ac79215f3b4c0c37822fac2'},
#  {'Descrição': 'Médico',
#   'Valor': 11.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Saúde',
#   'ID': '63fd5b61848a0cb2fb69a6848d2e23b6'},
#  {'Descrição': 'Volta',
#   'Valor': 20.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '06a819302d41a63ac1e031ae390eac76'},
#  {'Descrição': 'Panetone',
#   'Valor': 17.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'c04a932f6c519b23e5fd056ba3285a38'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 18.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '8611f9fe88d6e03d0e401e0619c08eac'},
#  {'Descrição': 'Mangás',
#   'Valor': 25.8,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '287914fd4e0eb072db18ddf854843512'},
#  {'Descrição': 'McDonalds',
#   'Valor': 33.5,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b2df6c5851027ecdb8de59b908ce4500'},
#  {'Descrição': 'Battle Royale',
#   'Valor': 16.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'b88227c70550979b7828d34d44b5f35d'},
#  {'Descrição': 'Korra',
#   'Valor': 7.74,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '21daa520a98196bbcf0e666f4deaedd1'},
#  {'Descrição': 'Uber mamai',
#   'Valor': 143.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '9b8c96003058ef06d8f186b1ef69c0c6'},
#  {'Descrição': 'Coxinha',
#   'Valor': 4.5,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b6343d22fc907dabd8e9172c65a0fc64'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 7.85,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '8b5b09bb65998c254a98b68307a80f88'},
#  {'Descrição': 'Pannetone',
#   'Valor': 11.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'bdbf4ca48a49598209b1a096aed12bf1'},
#  {'Descrição': 'Uber Taiko',
#   'Valor': 8.56,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '45ec8cd15554d6b6afbab3ebd978e8f7'},
#  {'Descrição': 'Yuzu',
#   'Valor': 84.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '4c83205cf83517e614e08df0453a55db'},
#  {'Descrição': 'Ferramentas',
#   'Valor': 36.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '583bc719df846724f697d183dd924074'},
#  {'Descrição': 'Taxi 15/02/2016',
#   'Valor': 24.1,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'e9a8ff11752462fe35e0c301be01859d'},
#  {'Descrição': 'Maquiagem momoi',
#   'Valor': 14.99,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'b623ea8bf7cf35f3aa93167d92f82c55'},
#  {'Descrição': 'Pannetone',
#   'Valor': 12.5,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'ba412edf251d040db85977bbf6cad898'},
#  {'Descrição': 'Pastel',
#   'Valor': 9.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '1532a5d6fdfe0fa1914aa359fe2878ca'},
#  {'Descrição': 'Uber 18/2/16',
#   'Valor': 40.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'ba16e66ab76a0d84a38812934a4b6d98'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 18.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '8611f9fe88d6e03d0e401e0619c08eac'},
#  {'Descrição': 'Pizza',
#   'Valor': 50.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'cf3881597f71f8ea9b8edf1cf674c4e7'},
#  {'Descrição': 'Pizza',
#   'Valor': 32.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'ea6c0821d2550e8239c361fdb73720a1'},
#  {'Descrição': 'Uber',
#   'Valor': 25.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '9da68bc94d5a4e3f467e9831f25cac73'},
#  {'Descrição': 'Marukai',
#   'Valor': 31.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '649519b705e608080c4826fffb317221'},
#  {'Descrição': 'Ikesaki',
#   'Valor': 68.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'd28dc0532f4bcd647cd93186da52a875'},
#  {'Descrição': 'Amolador',
#   'Valor': 18.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '46ae11c779548019476028819707492d'},
#  {'Descrição': 'Uber 29/02/2016',
#   'Valor': 7.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '81edce89f3da7ac0e98177359fbc02bf'},
#  {'Descrição': 'Uber 29/02/2016',
#   'Valor': 24.79,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '6159af5d472c4d91565553bfd17021f3'},
#  {'Descrição': 'Pão de açúcar',
#   'Valor': 38.86,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '8358d1a081ee6eef3307b9b019fefbbd'},
#  {'Descrição': 'Extra',
#   'Valor': 4.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '640a4d430a29a5938b9a60eb18298dec'},
#  {'Descrição': 'Pão de açúcar',
#   'Valor': 13.32,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '90e55330fa8641143e8b32e8601e71ca'},
#  {'Descrição': 'Salgado',
#   'Valor': 4.5,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '4b073602f7cd3ef4045d7c64a69559ec'},
#  {'Descrição': 'Padaria',
#   'Valor': 18.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'a918b5ccc64a360fc05fd0ab4f98e163'},
#  {'Descrição': 'Orange 4',
#   'Valor': 14.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '884cc6b7db929169e9516668fc7391f7'},
#  {'Descrição': 'Almoço momoi',
#   'Valor': 26.39,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '51a6401964a908ad256c4cb5a1f0e17b'},
#  {'Descrição': 'Salgado',
#   'Valor': 4.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '2bdef5c07b6654ce2f7a69e46c243ab2'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 10.65,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '1e993a94222c3bea86135909f0a7ee95'},
#  {'Descrição': 'Uber 22/2/2016',
#   'Valor': 21.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'ba464469adc9ce421573be131d47aac1'},
#  {'Descrição': 'Acerto CC Marilia',
#   'Valor': 30.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'd013db57c6b1c4ed3d72bb78ae928bca'},
#  {'Descrição': 'Curso de maquiagem',
#   'Valor': 70.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Educação',
#   'ID': '16ef3e9bce6b2c8bfc7cbf7f01d7fec0'},
#  {'Descrição': 'Diferença CC',
#   'Valor': 59.76,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '8d4911fd89297ed117a80482a2d9d01f'},
#  {'Descrição': 'Diferença CC',
#   'Valor': 62.57,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '48648b3f19004f01c59fbc6053f24665'},
#  {'Descrição': 'Remédios João',
#   'Valor': 31.97,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'b2072922b392a6a785d4e0240e24fd36'},
#  {'Descrição': 'Uber errado',
#   'Valor': 57.04,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '307622c54ad0b6d83803998816856676'},
#  {'Descrição': 'Uber ressarcido',
#   'Valor': 40.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Transporte',
#   'ID': '8976e6e25a72828dcccc4433729f139c'},
#  {'Descrição': 'Suco de laranja',
#   'Valor': 7.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '7d02419caea726ba72e9f4acda934662'},
#  {'Descrição': 'Lanche no CA',
#   'Valor': 4.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '556375625167d6cb14ac0ce468d22da2'},
#  {'Descrição': 'Padaria',
#   'Valor': 21.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'a904228773fb2e08e563a4c6bcc959bc'},
#  {'Descrição': 'Uber 3/3/16',
#   'Valor': 10.26,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'fe5cf5618d1227c123711ee40b973cee'},
#  {'Descrição': 'Remédio Marilia',
#   'Valor': 77.64,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '7bb3c5110dc3de72cf288b2afc54c5b4'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 18.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '8611f9fe88d6e03d0e401e0619c08eac'},
#  {'Descrição': 'Jasmin',
#   'Valor': 100.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '7b7cd08893cf5a80c3046234ab0b5cdd'},
#  {'Descrição': 'Uber 7/3/16',
#   'Valor': 21.8,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '670dd213158ae22f2dc141a8528ce677'},
#  {'Descrição': 'CA',
#   'Valor': 4.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Outros Gastos',
#   'ID': '2b4cd701136a1592d5b26868a416f9a9'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 23.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b08ab975f6ddc0dee0c5c10d38a386e2'},
#  {'Descrição': 'Paraíso doces',
#   'Valor': 15.9,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '31a4ff8764582bce954787ac4f1c8bc2'},
#  {'Descrição': 'Encargo',
#   'Valor': 6.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'daa56d91b46549b0fda338c4532860cb'},
#  {'Descrição': 'Pão',
#   'Valor': 22.35,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'a49702632fbb199d7f0b7ef8aa889fe1'},
#  {'Descrição': 'Webcam',
#   'Valor': 24.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'deb99f7861ff977cf92111251a5c7657'},
#  {'Descrição': 'Tênis 1/5',
#   'Valor': 40.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '24b63c2863bd9976b777ad15ed0652ba'},
#  {'Descrição': 'Pão',
#   'Valor': 2.53,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'e27ba5660f6dfc105eb8361cf07f969b'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 15.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '39f2a1a14088d2e8fa5c501df3d606da'},
#  {'Descrição': 'Playland',
#   'Valor': 10.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'df5bb758674953fbd02de0f37978aa1b'},
#  {'Descrição': 'uber 11/3/16',
#   'Valor': 32.34,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0bb169ebd588de027af70e1e7c880ae6'},
#  {'Descrição': 'uber 11/3/16',
#   'Valor': 32.34,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Transporte',
#   'ID': '0bb169ebd588de027af70e1e7c880ae6'},
#  {'Descrição': 'cosplay',
#   'Valor': 100.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '5ea246ca25a3c701b306f41492829a2e'},
#  {'Descrição': 'cosplay',
#   'Valor': 100.0,
#   'Data': '01/03/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '5ea246ca25a3c701b306f41492829a2e'},
#  {'Descrição': 'peruca',
#   'Valor': 70.0,
#   'Data': '01/03/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '63f7ba1acad145ce5ac7db6f4c9c22de'},
#  {'Descrição': 'JV - Quinto dia',
#   'Valor': 1447.0,
#   'Data': '01/04/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Receitas',
#   'ID': '7ce1adf76bf206790189630b50e2cea0'},
#  {'Descrição': 'JV - Adiantamento',
#   'Valor': 0.09,
#   'Data': '01/04/2016',
#   'Tipo': 'D',
#   'Categoria': 'Receitas',
# ...
#   'Valor': 199.6,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': 'fa6a85d8e91b47e1c7173a549052e6a3'},
#  {'Descrição': 'Uber',
#   'Valor': 1.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '2ebb011f2fc9d34c1eaa6f0d00301fb6'},
#  {'Descrição': 'BK',
#   'Valor': 12.8,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '2f5cc69668df05fd748a51b222b2270d'},
#  {'Descrição': 'Uber',
#   'Valor': 8.27,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '4db8c8f863cc7bf57e890621aa3d85c6'},
#  {'Descrição': 'MagaRock',
#   'Valor': 20.25,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '0b0ef5f3b39f77016d5d7ee8a49220e4'},
#  {'Descrição': 'Anco',
#   'Valor': 9.08,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '3848fc4d8bb5c91b0b67805dcc1399b7'},
#  {'Descrição': 'Padaria',
#   'Valor': 3.07,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '4406f9ec090b98543d0a8069d61517e3'},
#  {'Descrição': 'Uber',
#   'Valor': 10.68,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '135f2ebc3d36521917dfa34a865d763c'},
#  {'Descrição': 'Uber',
#   'Valor': 11.99,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '735ee72ce929e88b59b7554aa0c8b432'},
#  {'Descrição': 'Uber',
#   'Valor': 7.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '8aae472aab2bf5288e45c4f30f6aae1d'},
#  {'Descrição': 'Suco',
#   'Valor': 7.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b59a0ba4f7b87ac61b29b5fe95804fa0'},
#  {'Descrição': 'Uber',
#   'Valor': 9.17,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'cfd5c86ec5d016aaac6c5cbd8cae7c36'},
#  {'Descrição': 'Yuzu',
#   'Valor': 85.6,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '4bbfbeb1d77631ecc55a3021a7657aaf'},
#  {'Descrição': 'Uber Liberdade',
#   'Valor': 11.93,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'a38ec5f443c94abd10319e5615e18813'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 9.85,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '35f6997e1b4f12b89621c62f5bf15e33'},
#  {'Descrição': 'Uber Colação Aho',
#   'Valor': 30.11,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '438285b398ba564b19f8b78754dd078a'},
#  {'Descrição': 'Uber Colação Aho',
#   'Valor': 10.53,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '2dab41c200f84e2baf20f06366c9fa9c'},
#  {'Descrição': 'Bolo',
#   'Valor': 5.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'c256d3b6027218cfa18acef8789c99e0'},
#  {'Descrição': 'Horizon Chase',
#   'Valor': 5.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '762f17a878a1c7af4f09964ecb5c25c0'},
#  {'Descrição': 'Mercado',
#   'Valor': 50.43,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '9480ccd4b40ab77ea7c23d0316455eab'},
#  {'Descrição': 'Mercado',
#   'Valor': 52.51,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'e1d1a4f250c4b3956bf9b6d76855b5da'},
#  {'Descrição': 'Padaria',
#   'Valor': 13.02,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '08b7c6ac3e709531d99416e75f3f22b0'},
#  {'Descrição': 'Cartõeszinhos Marilia',
#   'Valor': 42.58,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '327ba4ed90c01946c2720e5d3457a9f4'},
#  {'Descrição': 'Bike Sampa',
#   'Valor': 5.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '66340e3d9afe4cd5c3980a8af59cd260'},
#  {'Descrição': 'Mercado',
#   'Valor': 22.35,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '4d1a1d4699a8e318675d57904820b2b5'},
#  {'Descrição': 'Pizza',
#   'Valor': 24.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '838a1a56f428b2cf626c59e76c5df25a'},
#  {'Descrição': 'Doces',
#   'Valor': 2.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '28e604eb6d61ed2d2c965f802cc34964'},
#  {'Descrição': 'Padaria',
#   'Valor': 1.46,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'f747278507ecf9e4c07806f34fab4c84'},
#  {'Descrição': 'Doces',
#   'Valor': 2.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '28e604eb6d61ed2d2c965f802cc34964'},
#  {'Descrição': 'Padaria',
#   'Valor': 3.21,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '5d13b8e1b49f0c582a0ad63c9e0b5394'},
#  {'Descrição': 'Mercado',
#   'Valor': 8.78,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '5e35aed50eb14b80a12bba7208088ff3'},
#  {'Descrição': 'Mercado',
#   'Valor': 6.08,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '57ac7e6a56cf69b790b08c64015e5a93'},
#  {'Descrição': 'Papelaria',
#   'Valor': 18.1,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'd6541bd2e94e3a3214da43af0a4671c0'},
#  {'Descrição': 'Mercado',
#   'Valor': 9.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '121570b9115e13d43804bdf196e85dbb'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 13.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '51208cf17911775bcb658fe44eacb5ca'},
#  {'Descrição': 'Habbibs',
#   'Valor': 16.61,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '2bfa89bffa35a0575aa6de979460f1dd'},
#  {'Descrição': 'Mercado',
#   'Valor': 32.69,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '66a34cc88c6185185e85bcfc429e1298'},
#  {'Descrição': 'Padaria',
#   'Valor': 4.98,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '395485044155651ee85e7b8cd3c5e055'},
#  {'Descrição': 'Mexicaníssimo',
#   'Valor': 48.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '6308a320d22a8e2e9f863b94f07ea03c'},
#  {'Descrição': 'Padaria',
#   'Valor': 3.13,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '3d1e5abed58f9a44d1d2d228916415fa'},
#  {'Descrição': 'Mercado',
#   'Valor': 30.02,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'cb8e40ce761a53819983781c3c99c4c2'},
#  {'Descrição': 'Padaria',
#   'Valor': 3.97,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'c3b8f89a7f272d5839f3b4849510a16b'},
#  {'Descrição': 'The Room',
#   'Valor': 3.59,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '3b1af5ce5747ac42e3f71419ee1c08f8'},
#  {'Descrição': 'Uber',
#   'Valor': 8.09,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '0f5d0f1830ff3f24f81e8d594bc6fa62'},
#  {'Descrição': 'Comidas Bunka',
#   'Valor': 18.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'f3fe7229502174fbfa9dd74435c4e4d2'},
#  {'Descrição': 'McDonalds chefe',
#   'Valor': 32.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '817f26e6ef9dbb2d59dbee6b108e2d4b'},
#  {'Descrição': 'Cosplay e blazer',
#   'Valor': 60.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'a7d84c29fbaceaf59eea314192fc8523'},
#  {'Descrição': 'Café da manhã',
#   'Valor': 23.48,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'aa3f9fcfae1c0a68ec9febefaa94eb26'},
#  {'Descrição': 'Takedas',
#   'Valor': 7.98,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '6d7a74cde7c09f1415301017fbea2e97'},
#  {'Descrição': 'Pizzas',
#   'Valor': 41.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b62226edc3f5d3078a6bb1f04e12df4b'},
#  {'Descrição': 'Uber',
#   'Valor': 7.09,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': '014f8eec56bba1976899b47f81f8268f'},
#  {'Descrição': 'Mercado',
#   'Valor': 18.29,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '42678cb4dc41a88e4c5c2450731f49d6'},
#  {'Descrição': 'Lovely Complex 4',
#   'Valor': 12.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '780de9920aa8446a39a941fa4322aab7'},
#  {'Descrição': 'Padaria',
#   'Valor': 5.71,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '241c2ff8662cacda3fe351af723f1bf6'},
#  {'Descrição': 'Sukiya',
#   'Valor': 32.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'd5d314acfc76d8d1ad3f804f73ab6fa8'},
#  {'Descrição': 'Padaria',
#   'Valor': 11.8,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '32ba8f9381a425e0c125bf1bd1db6488'},
#  {'Descrição': 'Vagabundo 7',
#   'Valor': 17.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '8dcd27caa9042564374cb698d3329bef'},
#  {'Descrição': 'Uber',
#   'Valor': 15.23,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Transporte',
#   'ID': 'bc8c398ee06f45038106124fd0aafcb4'},
#  {'Descrição': 'Padaria',
#   'Valor': 2.92,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '91355c864a18c8f5831895b7be961d70'},
#  {'Descrição': 'Doces',
#   'Valor': 6.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '0cf9525ab6a06ffd8dcc9f8effa88b98'},
#  {'Descrição': 'Padaria',
#   'Valor': 5.56,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '5b01274cad115e04f58313b2d1be070e'},
#  {'Descrição': 'Caldo de cana',
#   'Valor': 7.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'c7546a133c02cb6753647928ad8a607f'},
#  {'Descrição': 'Pastel',
#   'Valor': 10.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'fd0497f8958e9340b844751ec9bd4142'},
#  {'Descrição': 'Panelas',
#   'Valor': 55.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': 'b919d76dc44cc1c2053505bad9a3565a'},
#  {'Descrição': 'Dogão',
#   'Valor': 4.14,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '9fe04571805c0b943a0c8ee541f27fb8'},
#  {'Descrição': 'Dogão',
#   'Valor': 12.87,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '9042397d6f3e2318a55bbb8ebd34eb7a'},
#  {'Descrição': 'Padaria',
#   'Valor': 4.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'b1a813cf9499a80d2b201bdc20f85f34'},
#  {'Descrição': 'Tanka',
#   'Valor': 86.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '7e17e5f50305ae6c1be3054f075fd971'},
#  {'Descrição': 'Daiso João',
#   'Valor': 10.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '12f9f1f01105bdcb516f4225d03a390f'},
#  {'Descrição': 'Daiso Marilia',
#   'Valor': 24.07,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '1d23595d0b7286366235cfd4cbe008d1'},
#  {'Descrição': 'Calças João',
#   'Valor': 152.95,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '8b88fee9ea59707ef8afb9b06d94f629'},
#  {'Descrição': 'Sukiya',
#   'Valor': 43.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '501f703940d1a8bf3a626d0421f2d9f8'},
#  {'Descrição': 'Daiso',
#   'Valor': 7.99,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Casa',
#   'ID': '9c93d1da3f2e41e0e4171ae1abc87f73'},
#  {'Descrição': 'McDonalds',
#   'Valor': 55.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '6f25d584944b0ab12e4ad826d83c09bc'},
#  {'Descrição': 'Padaria',
#   'Valor': 18.61,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'be6be56c75a8c3837f61e1ffbe932fbd'},
#  {'Descrição': 'Manga momoi',
#   'Valor': 14.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': 'b2ca5853c2cf429debdcd0c46262f9bc'},
#  {'Descrição': 'Padaria',
#   'Valor': 1.74,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'e77bbebc40e6d39c3ea0d0d7865d02af'},
#  {'Descrição': 'Cosplay',
#   'Valor': 50.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '96bccd5d124e52d5506187d60799b215'},
#  {'Descrição': 'Cosplay',
#   'Valor': 36.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '6fa29992cfdc3f0fbeb9a629c178f5bd'},
#  {'Descrição': 'Sukiya',
#   'Valor': 21.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '7808b16a3684f13e085512c93850ce33'},
#  {'Descrição': 'Sydonia 6',
#   'Valor': 17.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Lazer e Entretenimento',
#   'ID': '0273b06672ad58097041eba3ef8dfe8c'},
#  {'Descrição': 'Padaria',
#   'Valor': 5.53,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '34947d39c5734c65002d29aa8427a753'},
#  {'Descrição': 'Sukiya',
#   'Valor': 21.5,
#   'Data': '01/09/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Delivery',
#   'ID': '7808b16a3684f13e085512c93850ce33'},
#  {'Descrição': 'Cosplay',
#   'Valor': 25.0,
#   'Data': '01/09/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'e206237bc0de1b3714cf7ca9d96b73af'},
#  {'Descrição': 'Cosplay',
#   'Valor': 18.0,
#   'Data': '01/09/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Despesas Pessoais',
#   'ID': '366adbc80dcc5dbdcb85703cc438cb32'},
#  {'Descrição': 'Variação cambial',
#   'Valor': 0.23,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': 'f61bfbf317b4e951ca0511e82c62bbb9'},
#  {'Descrição': 'Doces',
#   'Valor': 7.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'e96ac26e64d04e0047f69eadc7480117'},
#  {'Descrição': 'Dia',
#   'Valor': 21.36,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'e39cd87d1bc73e682f772f2cbd4e491e'},
#  {'Descrição': 'Padaria',
#   'Valor': 8.49,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '797505145118d12d749a429651525a99'},
#  {'Descrição': 'Feijoada',
#   'Valor': 13.8,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': 'e0d175b5d42007df4b6b33828ae1cb3a'},
#  {'Descrição': 'Coquinha',
#   'Valor': 4.89,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Mercado',
#   'ID': '3dd3e3aa84bdc440e038b7410acdf2a5'},
#  {'Descrição': 'Pizza',
#   'Valor': 43.9,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'ec15477389939d000ee6b1cebbd6c849'},
#  {'Descrição': 'Pizza',
#   'Valor': 21.95,
#   'Data': '01/09/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Delivery',
#   'ID': '18286d71161dad66ca89ae2ef6cb33cd'},
#  {'Descrição': 'Comidas UpAbc',
#   'Valor': 6.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'ed78f0d3c1b419830fd4267632fab69f'},
#  {'Descrição': 'HP Stuff',
#   'Valor': 14.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Despesas Pessoais',
#   'ID': 'b4947c82ddaf90c951b89cd26a25ea94'},
#  {'Descrição': 'Comida UpAbc',
#   'Valor': 10.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'b08f7d869a9600c558abaa82175b8818'},
#  {'Descrição': 'McDonalds UpAbc',
#   'Valor': 32.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '0de3effb6e929c08e834edd295f8e1cd'},
#  {'Descrição': 'McDonalds UpAbc',
#   'Valor': 16.25,
#   'Data': '01/09/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Delivery',
#   'ID': 'f05c6e320e1ca4d87ea41622f99032e3'},
#  {'Descrição': 'McDonalds UpAbc',
#   'Valor': 8.5,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': '0afbc106428e5375a4ea91eec772b204'},
#  {'Descrição': 'McDonalds UpAbc',
#   'Valor': 4.25,
#   'Data': '01/09/2016',
#   'Tipo': 'RE',
#   'Categoria': 'Delivery',
#   'ID': 'c1e2278c1d748d4a8a66ea07df0b441d'},
#  {'Descrição': 'Empréstimos',
#   'Valor': 3.68,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Financeiro',
#   'ID': '9e9d9b0ba83c674986eaffdbf03106a8'},
#  {'Descrição': 'Pastel',
#   'Valor': 20.0,
#   'Data': '01/09/2016',
#   'Tipo': 'D',
#   'Categoria': 'Delivery',
#   'ID': 'edff30d394dcae334aca9eadeac38705'},
#  ...]
